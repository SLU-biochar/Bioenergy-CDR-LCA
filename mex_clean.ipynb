# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Libraries,-classes-&amp;-functions" data-toc-modified-id="Libraries,-classes-&amp;-functions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Libraries, classes &amp; functions</a></span></li><li><span><a href="#Project-initialisation" data-toc-modified-id="Project-initialisation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Project initialisation</a></span><ul class="toc-item"><li><span><a href="#Project-name,-final-products,-systems-to-study" data-toc-modified-id="Project-name,-final-products,-systems-to-study-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Project name, final products, systems to study</a></span></li></ul></li><li><span><a href="#Calculation-set-up" data-toc-modified-id="Calculation-set-up-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Calculation set-up</a></span><ul class="toc-item"><li><span><a href="#Systems-studied,-functional-units,-impact-categories" data-toc-modified-id="Systems-studied,-functional-units,-impact-categories-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Systems studied, functional units, impact categories</a></span></li><li><span><a href="#Calculate-for-first-3-FUs" data-toc-modified-id="Calculate-for-first-3-FUs-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Calculate for first 3 FUs</a></span></li><li><span><a href="#Alternative-Calculation---CDR-as-FU" data-toc-modified-id="Alternative-Calculation---CDR-as-FU-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Alternative Calculation - CDR as FU</a></span></li><li><span><a href="#Systems-studied,-functional-units,-impact-categories" data-toc-modified-id="Systems-studied,-functional-units,-impact-categories-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Systems studied, functional units, impact categories</a></span></li><li><span><a href="#Calculate-for-CDR-FU" data-toc-modified-id="Calculate-for-CDR-FU-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Calculate for CDR FU</a></span></li><li><span><a href="#setup-for-analysis" data-toc-modified-id="setup-for-analysis-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>setup for analysis</a></span><ul class="toc-item"><li><span><a href="#define-lambdas-&amp;-deltas" data-toc-modified-id="define-lambdas-&amp;-deltas-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>define lambdas &amp; deltas</a></span></li></ul></li></ul></li><li><span><a href="#Analysis" data-toc-modified-id="Analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Analysis</a></span><ul class="toc-item"><li><span><a href="#contribution-analysis" data-toc-modified-id="contribution-analysis-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>contribution analysis</a></span><ul class="toc-item"><li><span><a href="#set-up-groups" data-toc-modified-id="set-up-groups-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>set up groups</a></span></li><li><span><a href="#check-that-it-makes-sense-by-comparing-to-old-ca" data-toc-modified-id="check-that-it-makes-sense-by-comparing-to-old-ca-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>check that it makes sense by comparing to old ca</a></span></li><li><span><a href="#set-up-for-distributions" data-toc-modified-id="set-up-for-distributions-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>set up for distributions</a></span></li><li><span><a href="#plotting-distrib-final-version" data-toc-modified-id="plotting-distrib-final-version-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>plotting distrib final version</a></span></li></ul></li><li><span><a href="#Global-Sensitivity-Analysis" data-toc-modified-id="Global-Sensitivity-Analysis-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Global Sensitivity Analysis</a></span><ul class="toc-item"><li><span><a href="#get-sobols" data-toc-modified-id="get-sobols-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>get sobols</a></span></li><li><span><a href="#get-delta-sobols" data-toc-modified-id="get-delta-sobols-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>get delta sobols</a></span></li></ul></li><li><span><a href="#pairwise-comparison" data-toc-modified-id="pairwise-comparison-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>pairwise comparison</a></span></li></ul></li><li><span><a href="#biomass-indicators" data-toc-modified-id="biomass-indicators-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>biomass indicators</a></span></li><li><span><a href="#Other-stuff" data-toc-modified-id="Other-stuff-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Other stuff</a></span><ul class="toc-item"><li><span><a href="#create-df-w-params-&amp;-score" data-toc-modified-id="create-df-w-params-&amp;-score-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>create df w params &amp; score</a></span></li><li><span><a href="#save-df:s-to-excel" data-toc-modified-id="save-df:s-to-excel-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>save df:s to excel</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Algebraic comparative LCAs of bioenergy systems

# %% [markdown]
# ## Libraries, classes & functions

# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
from matplotlib import style
style.available
style.use('seaborn')

import numpy as np
import brightway2 as bw2
import itertools

from IPython.display import display, Math

# Custom utils defined for inter-acv
from lca_algebraic import *
from lca_algebraic.stats import * 
import lca_algebraic
from sympy import *
import re

from copy import deepcopy

# %%
## IPCC method GWP100
IPCC = [method for method in bw2.methods if "IPCC 2013" in str(method) 
        and "GWP 100" in str(method) 
        and "LT" not in str(method)
        and "V1" not in str(method)]
IPCC_unit = [r'kg $CO_2$-eq']

## Helping functions
def rev_dict(d):
    '''
    reverse the k,v of the dictionary
    input parameter: a dictionary (any)
    object returned: the same dictionary, with keys and values reversed
    example
    a = {'key': value}
    b = rev_dict(a)
    b is now the dictionary {value: 'key'}
    '''
    return {v: k for k, v in d.items()}

def reindex_dict(d):
    ''' 
    reindexes a dictionary where the keys are integers, sorted
    input: a dictionary with integers as keys
    output: a dictionary with the keys numbered accordingly
    example
    a = {2: 'value1',
        4: 'value2',
        5: 'value3'}
    b = reindex_dict(a)
    b is now the dictionary
    {1: 'value1',
    2: 'value2',
    3: 'value3'}
    '''
    return {i:k[1] for i,k in enumerate(d.items())}

def readable_dict(d):
    ''' d = dict of format key=interger, value=tuple,activity key
    '''
    return {k:bw2.get_activity(v)['name'] for k,v in d.items() }


def Y_from_dict(fu, A, A_rows, A_cols):
    '''Creates Y vector from fu dictionary and a square matrix A and its col/row names
    Basically Y is an array where every row is correspondent to a row (product) in A
    And the elements in Y represent how much of each product is demanded by fu
    input: functional unit, technosphere matrix A, rows of A (dictionary), columns of A (dictionary)
    output: an array Y
    example
    fu = {(fg, 'soup-heat'):10}
    A = Matrix[...]
    A_rows = {...}
    A_cols = {...} (not really necessary as an input?)
    Y = Y_from_dict
    
    Y is now the array
    
    0
    0
    10
    0
    0
    0
    .
    .
    .
    
    where every row is correspondent to the product rows in A
    and row 3 in A is the row for product of heat
    '''
    
    # build the FU as a sympy vector 
    Y = SparseMatrix(A.shape[0], 1, 0)
    for k, v in A_rows.items():
        Y[v, 0] = fu[k] if k in fu else 0
    return Y

def createLambda(expr):
    '''
    Returns a lambda from a **scalar** sympy expression
    '''
    expr_symbols = [str(k) for k in expr.free_symbols]
    # params_in_use need to have the correct name for enumeration Parameters
    params_in_use = {}
    for param in lca._param_registry().values():
        for name in param.names(): # one 1 name if not enumParam, several if enumParam
            if name in expr_symbols:
                params_in_use[param.name] = param  # get the name of the enumParam or Param

    return lca.LambdaWithParamNames(expr,
                                    expanded_params=None, # is automatically created in the init via: _expand_param_names(self.params)
                                    params=params_in_use,
                                    sobols=None)

def evalSympy(sympyExpr):
    '''
    Input:
    - sympyExpr : a scalar or a matrix

    Output:
    - object of same shape as the sympyExpr, but numeric value

    Evaluation is done using the lca algebraic functions, which take the default values for each parameter

    '''
    
    # create dupplicate of sympyExpr
    evalExpr = deepcopy(sympyExpr)
    
    # loop on all items of sympyExpr
    if isinstance(sympyExpr, SparseMatrix):
        # it is a matrix, we loop on all its coefficients
        for i in range(sympyExpr.shape[0]):
            for j in range(sympyExpr.shape[1]):
                lbd = createLambda(sympyExpr[i,j])
                evalExpr[i,j] = postMultiLCAAlgebric2(IPCC, [lbd])
                
    else:
        # it is not a matrix, we assume it is a scalar
        lbd = createLambda(sympyExpr) # create a lambdas 
        evalExpr = postMultiLCAAlgebric2(IPCC, [lbd]) # overwrite value in evalExpr

    return evalExpr

### Class for performing comparative LCA in a streamlined fashion, and with algebraic expressions
class CLCA: # CLCA = ComparativeLCA (and not consequential LCA)
    
    def __init__(self, FunctionalUnits=None, SystemsCompared=None, SystemsNotCompared=None, FinalProducts=None, ImpactCategories=IPCC):
        '''
        create new object in CLCA class
        defines functional units, systems to compare, final products, saves names for systems compared and final products,
        defines impact categories (defualt GWP100, IPCC defined in 3.1)
        checks if all systems to compare are in the same database and prints a warning if they're not
        defines Combinations, CombinationsMatrices, InventoryScores and ImpactScores (empty or None)
        
        '''
        
        self.FunctionalUnits = FunctionalUnits # as list of dictionary 
        self.SystemsCompared = SystemsCompared # as list of keys
        self.SystemsNotCompared = SystemsNotCompared # so that we can remove them from A
        self.FinalProducts = FinalProducts # as list of keys of SOUPs, referring to products 
        
        self.SystemsCompared_Names = { k: bw2.get_activity(k)['name'] for k in self.SystemsCompared }
        self.FinalProducts_Names = { k: bw2.get_activity(k)['name'] for k in self.FinalProducts }
        
        self.ImpactCategories = ImpactCategories
        
        self.ForegroundDatabase = self.SystemsCompared[0][0]# assuming all activities in the same foreground database
        check_fgdb = [self.SystemsCompared[k][0] for k,s in enumerate(self.SystemsCompared)]
        if len(set(check_fgdb))>1:
            print("Systems compared not saved in the same foreground database. Warning - This case is not supported by the matrix generating functions")
        
        self.Combinations = None # number of combinations    
        self.CombinationsMatrices = {} #empty dictionnary
        self.InventoryScores = None 
        self.ImpactScores = None
    
    def gen_matrices(self):
        '''
        Generate a sympy technosphere and biosphere matrices for the foreground + compressed background system:
        Technosphere matrix A (A_NS), biosphere matrix B (B_NS), activity dictionary (A_NS_columns), 
        product dictionary (A_NS_rows), background activities (BackgroundActivities) and biosphere dictionary (B_NS_rows)
        based on foreground database
        if a column in the A is zero, an exception is raised
        '''

        ## Helping functions
        act_symbols = dict()  # Dict of  act = > symbol
        def _slugify(str) :
            '''
            every symbol in a string that is not 0-9, a-z or A-Z is replaced with '_'
            input: string
            output: string with no other symbols than 0-9, a-z, A-Z and _
            example
            s1 = 'a!b%c='
            s2 = _slugify(s1)
            s2 is now the string 'a_b_c_'
            '''
            return re.sub('[^0-9a-zA-Z]+', '_', str)

        def act_to_symbol(db_name, code):
            '''
            ...
            '''

            act = getActByCode(db_name, code)
            name = act['name']
            base_slug = _slugify(name)

            slug = base_slug
            i = 1
            while symbols(slug) in act_symbols.values():
                slug = f"{base_slug}{i}"
                i += 1

            return symbols(slug)

        def _getAmountOrFormula(ex):
            """ Return either a fixed float value or an expression for the amount of this exchange"""
            if 'formula' in ex:
                try:
                    return parse_expr(ex['formula'])
                except:
                    _eprint("Error while parsing formula '%s' : backing to amount" % ex['formula'])

            return ex['amount']

        ## Step 1
        ## Determine the size of the factorised technosphere A and biosphere B matrices
        
        ## A = (p + n) x (f + n), where: 
        ## f = nb of activities in foreground databases, and
        ## n = nb of unique bg activities used in foreground database
        ## p = nb of unique products genereted by foreground system
        
        ## B = b x (f + n), where:
        ## b = nb of unique direct emissions in foreground system
        
        fgdb = bw2.Database(self.ForegroundDatabase)
        fgdb_data = sorted(fgdb.load().items()) # as a sorted list

        f = 0 # number of foreground activities
        n = 0 # number of background activities used
        p = 0 # number of foreground products
        b = 0 # number of direct emissions
        list_n = []
        list_p = []
        list_b = [] 
        for k, v in fgdb_data: 
            if "# asTech" not in v['name']:
                f+=1 # go to next iteration, # we don't want these processes in the matrix
            for exch in v['exchanges']:
                # encountered a new background input
                if exch['input'][0] not in [ self.ForegroundDatabase, 'biosphere3' ] and exch['input'] not in list_n:
                    n+=1
                    list_n.append(exch['input'])    
                # encountered a new product
                if exch['input'][0] in [ self.ForegroundDatabase ] and exch['input'] not in list_p:
                    p+=1
                    list_p.append(exch['input'])   
                # encountered a new bioshere emission in by a foreground activity
                if exch['input'][0] in [ 'biosphere3'] and exch['input'] not in list_b:
                    b+=1
                    list_b.append(exch['input']) 
        
        ## initialize sparse matrix, with 0
        A = SparseMatrix(p+n, f+n, 0) # Technosphere matrix ... rectangular 
        B = SparseMatrix(b, f+n, 0) # Biosphere matrix ... rectangular 
        
        ZeroVector = SparseMatrix(p+n,1,0) # A Zero Activity, to check equality to 0 of columns
        
        ## Step 2
        ## Loop on data, to generate matrices expressions
        
        ## Initialise dictionaries
        c = 0 # column counter for A & B
        activity_dict = {} # columns of the technosphere matrix A
        r = 0 # row counter for A
        product_dict = {} # rows of the technosphere matrix A
        rb = 0 # row counter for B
        biosphere_dict = {} # # rows of the biosphere matrix B

        bg_act_needed = {}

        ## for loop on all activities from the foreground database
        for act_tpl, act_data in fgdb_data:
            
            activity_dict[act_tpl] = c # activity assigned this c col number
            Ac = c # Ac is the pointer for all the coefficients in that column for that loop 
            
            if "# asTech" in act_data['name']:
                continue # we go to next item

            ## for loop on all its exchanges
            for exch in act_data['exchanges']:
                if exch['type'] == 'biosphere':
                ## if exch with biosphere 
                    if exch['input'] in biosphere_dict:
                        Br = biosphere_dict[exch['input']]
                    else:
                        Br = rb
                        biosphere_dict[exch['input']] = Br
                        rb+=1
                    formula = _getAmountOrFormula(exch)
                    B[Br, Ac] = formula

                elif exch['input'][0] in [ self.ForegroundDatabase ]: 
                ## if exch within foreground db:
                    sign = +1 if exch['type'] == 'production' else -1
                    ## insert coefficient in the sympy sparse matrix, with amount = sympy expression
                    formula = _getAmountOrFormula(exch)

                    if exch['input'] in product_dict:
                        Ar = product_dict[exch['input']]
                    else:
                        Ar = r
                        product_dict[exch['input']] = Ar
                        r+=1
                    A[Ar, Ac] = sign*formula                    

                elif exch['input'][0] not in [ self.ForegroundDatabase, 'biosphere3' ]:
                ## if exch in bg db: we have 2 things to do
                ## 1) Add a diagonal coefficient for that background activity producing itself
                ## 2) Add the non-diagonal coefficient in the column of the current activity !
                
                    sym = act_to_symbol(exch['input'][0], exch['input'][1])
                    ## 
                    if exch['input'] in product_dict:
                        Ar = product_dict[exch['input']]
                        formula = _getAmountOrFormula(exch)
                        A[Ar, Ac] = -1*formula
                        
                    else: # we encounter a new activity, which does not yet have a col number
                        c = c + 1 # we assign a new number to c for that background activity
                        Ar = r # we also assign a new product (though different couting technique-artefact of shitty development)
                        r+=1
                        product_dict[exch['input']] = Ar
                        activity_dict[exch['input']] = c
                        A[Ar, c] = 1 # so-called diag coefficient (maybe it's not on the diag)
                        
                        formula = _getAmountOrFormula(exch)
                        A[Ar, Ac] = -1*formula
                                        
                    bg_act_needed[exch['input']] = sym ## and add background activity to list of activities for which we need EF values (to calc separately in a MultiLCA with many FUs rather than here)

            # back in first for loop
            c = c + 1 # increase the counter to go to the next activity
        
        self.A_NS = A
        self.A_NS_rows = product_dict
        self.A_NS_rows_rev = rev_dict(product_dict)
        self.A_NS_columns = activity_dict
        self.A_NS_columns_rev = rev_dict(activity_dict)
        self.BackgroundActivities = bg_act_needed
        self.B_NS = B
        self.B_NS_rows = biosphere_dict
        
        def check_zero_columns(A, A_columns):
            '''Check if there are columns in A that are zero
            If there are columns equal to zero, an exception in raised
            '''
            zeroActivities = {}
            for i in range(A.shape[1]): # loop on columns
                if A[:,i] == ZeroVector:
                    zeroActivities[i] = rev_dict(A_columns)[i]
            if len(zeroActivities) > 0:
                self.A_NS_Zeros = zeroActivities
                raise Exception('Technosphere matrix A_NS has %i activities with null coefficients. The matrix is not invertible... Check data or matrix parser' %(len(zeroActivities)))
        check_zero_columns(self.A_NS, self.A_NS_columns)
        
    def calc_inventories(self):
        '''
        Loop on all fu, system, and soup combinations...
        For each combination:
        create sqaure A matrix
        save functional unit, syste, type of combination (unique or multiple), A, A_col_names, X and X_NS in CombinationsMatrices
        added for now: also save soup_removed in CombinationsMatrices
        '''
        
        def calc_inventory(fu, A, A_col_names):
            '''
            For a unique given system combination (i.e. S, FU, and closing SOUPs) calculates the inventory
            Returns the inventory with indices referring to the ones in the non-square matrix, as sympy vector
            What is the difference between X and X_NS? Different shapes - X_NS has the same columns as A_NS (non-square tech matrix)
            X has the same columns as square A
            '''
            # build the FU as a sympy vector 
            Y = SparseMatrix(A.shape[0], 1, 0)
            for k, v in self.A_NS_rows.items():
                Y[v, 0] = fu[k] if k in fu else 0
            # this will only give the solution as in "amount" of each activity needed
            X = A.inv(method='GE')*Y
            
            # X conversion to other row indices, with 0 whenever relevant
            
            # mapping from A_col_names to A_NS_col_names: one dictionary is larger than the other
            mapping = {col_A : self.A_NS_columns[name] for name, col_A  in A_col_names.items() }
    #        for name, col_A  in A_col_names.items():
     #           mapping[col_A] = self.A_NS_columns[name]
            X_NS = SparseMatrix(self.A_NS.shape[1], 1, 0)
            for i,j in mapping.items():
                X_NS[j,0] = X[i,0] 
            
            return X, A_col_names, X_NS
        
        def squared_matrix(fu, sys, SoupToRemove):
            ''' 
            Generates the square sympy matrix by removing from A
            - the two systems that are not studied in this combination
            - one SOUP
            
            inputs: fu, system and SoupToRemove (found in function SystemCombinations)
            returns A, A column names and soups_to_remove
            '''
            
            A = self.A_NS.copy()
            A_col_names = self.A_NS_columns
            A_row_names = self.A_NS_rows

            rev_A_col_names = rev_dict(A_col_names)
            rev_A_row_names = rev_dict(A_row_names)            
            
            # non-studied systems right now
            systems_to_remove = [A_col_names[s] for s in self.SystemsCompared if s != sys]  # list of column nbrs to remove
            
            # combinations of closing systems
            # to_remove = all_products.difference(diff1).difference(diff2).difference(cb)
            soup_to_remove = [A_col_names[s] for s in SoupToRemove]
            
            if self.SystemsNotCompared == None: # if all systems should be studied
                systems_not_studied = []
            else:
                systems_not_studied = [A_col_names[s] for s in self.SystemsNotCompared]
            
            # all columns to remove
            columns_to_remove = systems_to_remove + soup_to_remove + systems_not_studied # list concatenation
            columns_to_remove.sort() # inplace sorting of list items
            
            off=0
            for c in columns_to_remove:
                A.col_del(c-off) # column deleted,
                off += 1 # offset in column number
                rev_A_col_names.pop(c)
            
            old_A_col_names = rev_dict(rev_A_col_names)
            rev_A_col_names = reindex_dict(rev_A_col_names) #reindexing col
            new_A_col_names = rev_dict(rev_A_col_names)
            
            return A, new_A_col_names, rev_A_col_names, old_A_col_names
        
        def SystemCombinations(fu, sys):
            '''
            Find SOUP to remove for a given fu and system
            '''
            s = bw2.get_activity(sys)
            set_system = [] # an empty set
            for e in s.exchanges():
                if e['type'] == 'production':
                    set_system.append(e['input'])
                elif e['type'] == 'technosphere' and e['amount']<0:
                    set_system.append(e['input'])
            set_system = set(set_system) # set of products produced by system

            set_fu = [ f for f in fu.keys() ]
            set_fu = set(set_fu) # set of products demanded by fu
            
            # since we only have fu:s demanding 1 product, there will be an intersection 
            SoupToRemove = set_fu.intersection(set_system)
            if len(SoupToRemove) == 0:
                print('There is no product both demanded by fu and produced by system')
            
            if len(SoupToRemove) > 1:
                print('There are several products that are both demanded by fu and produced by system')
            
            return SoupToRemove
        
        
        ## Step 1
        i = 1
        for fu in self.FunctionalUnits: # first loop on FU, because we make comparisons between systems for the same FU
            for sys in self.SystemsCompared:
                # calculate how many soup combinations are possible in that specific case
                SoupToRemove = SystemCombinations(fu, sys)
                
                A, A_col_names, A_rev_col_names, old_cols = squared_matrix(fu, sys, SoupToRemove)
                self.CombinationsMatrices[i] =  {'fu': fu,
                                                'system':sys,
                                                'A': A,
                                                'A_col_names': A_col_names,
                                                'A_rev_col_names': A_rev_col_names,
                                                'old_col_nbs': old_cols
                                                    }
                X, X_col_names, X_NS = calc_inventory(fu, A, A_col_names)
                self.CombinationsMatrices[i]['X'] = X
                self.CombinationsMatrices[i]['X_NS'] = X_NS
                i += 1
        
    def calc_ImpactEquation(self, custom_symbols=None, highlited_foreground=None):
        '''
        Generic impact equation
        Assigns every activity in the database with an EF if it has direct emissions
        highlited_foreground : a list of activities that we want to use to express the generic impact equation, if present in the matrix,
        the results are projected on these activities - can be used to exihbit some parameters, and hide some background details
        '''
        
        ## Step 1
        ## Assign EF symbols for each activity in foreground (if it has direct emissions) and background
        EFs = Matrix( [ symbols('EF_'+str(i)) for i,x in enumerate(self.A_NS_columns) ] )
        
        ## Step 1.5 Check if the given process has any direct emissions, if not, we can also skip that EF and set it to 0
        def checkZero(B, B_col_names):
            '''Check if some columns have only 0'''
            ZeroVector = SparseMatrix(B.shape[0], 1, 0)
            isZero = {}
            for i in range(B.shape[1]):
                if B[:,i] == ZeroVector:
                    isZero[i] = rev_dict(B_col_names)[i]
            
            return isZero
        
        isZero = checkZero(self.B_NS, self.A_NS_columns) # B has same columns as A
        toSubs = {'EF_'+str(k):0 for k,v in isZero.items() if v[0] in ['MyThesisv2'] }
        EFs = EFs.subs(toSubs)
        
        ## Step 2
        ## Loop on all combinations, and save equation
        for c in self.CombinationsMatrices.keys():
            X_NS = self.CombinationsMatrices[c]['X_NS']
            S_NS = EFs.T*X_NS
            self.CombinationsMatrices[c]['S_NS'] = S_NS[0]

    def calc_specificImpact(self, reLoadParams=False):
        '''Here, the background is actually calculated for the given impact categories !'''
        
        EFs = SparseMatrix(len(self.ImpactCategories), self.A_NS.shape[1], 0) # as many columns as activities, as many rows as impact categories
        
        methods = self.ImpactCategories # a list of impact categories
        bg_act_fu = [ {bg:1} for bg in self.BackgroundActivities.keys()]
        ## for each combination
            ## we have the inventory
            
        ## for each method
        ## calc background impacts
        def _multiLCA(activities, methods):
            """Simple wrapper around brightway API"""
            bw2.calculation_setups['process'] = {'inv': activities, 'ia': methods}
            lca = bw2.MultiLCA('process')
            
            cols = [act for act_amount in activities for act, amount in act_amount.items()]
            return pd.DataFrame(lca.results.T, index=[method_name(method) for method in methods], columns=cols)

        bg_lca = _multiLCA(bg_act_fu, methods) # returns a df
        # convert df to a nice useable dictionary here         
        bg_scores = {}
        for imethod, method in enumerate(methods) :
            for iact, act in enumerate(bg_act_fu) :
                col = self.A_NS_columns[list(act)[0]]
                bg_scores[(col, list(act)[0], method)] = bg_lca.iloc[imethod, iact]
                
                EFs[imethod, col] = bg_lca.iloc[imethod, iact]
                
        self.BackgroundActivitiesScores = bg_scores
        
        ## calc foreground direct emissions  
        def _getAmountOrFormula(ex):
            """ Return either a fixed float value or an expression for the amount of this exchange"""
            if 'formula' in ex:
                try:
                    return parse_expr(ex['formula'])
                except:
                    _eprint("Error while parsing formula '%s' : backing to amount" % ex['formula'])

            return ex['amount'] 
        
        def directEmissionsFromAct(act):
            '''Creates new activities, in a separate database, with the 
            direct biosphere emissions of a foreground activities
            OBS: the database named DirectEmissions must exist in the project'''
            dbname = act[0]
            code = act[1]
            a = getActByCode(dbname, code)
            bioExchanges = {}
            for exc in a.exchanges():  
                if exc['input'][0] == BIOSPHERE3_DB_NAME :
                    bioAct = getActByCode(BIOSPHERE3_DB_NAME, exc['input'][1])#_getDb(BIOSPHERE3_DB_NAME).get()
                    if bioAct not in bioExchanges: # in case the same biosphere exchange appears more than once
                        bioExchanges[bioAct] = _getAmountOrFormula(exc)
                    else:
                        bioExchanges[bioAct] += _getAmountOrFormula(exc) 
            name = a['name']+'_DirectEmissions'
            code_to_find = code+'#DirectEmissions'
            res = newActivity('DirectEmissions', name, 'unit', bioExchanges, code=code_to_find)
            return res

        def checkNotZero(B, B_col_names):
            '''Check if some columns have only 0'''
            ZeroVector = SparseMatrix(B.shape[0], 1, 0)
            notZero = {}
            noSymbols = {}
            hasSymbols = {}
            for i in range(B.shape[1]):
                if B[:,i] != ZeroVector:
                    notZero[i] = rev_dict(B_col_names)[i]
                    if len(B[:,i].free_symbols) == 0:
                        noSymbols[i] = rev_dict(B_col_names)[i]
                    else:
                        hasSymbols[i] = rev_dict(B_col_names)[i]

            return notZero, noSymbols, hasSymbols
        
        notZero, noSymbol, hasSymbol = checkNotZero(self.B_NS, self.A_NS_columns) # B has same columns as A
        # dict, col: key
        
        ## no symbol
        noSymbolDE = {}
        for k,v in noSymbol.items(): # k = col number, v = activity code
             noSymbolDE[k] = directEmissionsFromAct(v)
        fg_act_fu = [ {fg.key:1} for fg in noSymbolDE.values()]
        fg_lca = _multiLCA(fg_act_fu, methods) # returns a df
        
        # convert df to a nice useable dictionary here         
        fg_scores = {}
        for imethod, method in enumerate(methods) :
            for iact, act in enumerate(fg_act_fu) :
                key_in_DEdb = list(act)[0]
                cd = key_in_DEdb[1].replace('#DirectEmissions', '') # remove the extra tag
                key_in_FGdb = tuple((self.ForegroundDatabase, cd))
                col = self.A_NS_columns[ key_in_FGdb ]
                fg_scores[(col, key_in_FGdb, method)] = fg_lca.iloc[imethod, iact]
                EFs[imethod, col] = fg_lca.iloc[imethod, iact]

        self.EFs = EFs  
        
        self.ForegroundActivitiesScores = fg_scores

        ## has symbols
        if len(hasSymbol) > 0:
            print('There are %i activities with direct emissions with formulas in biosphere exchange. Functionality not yet supported. 0 instead..' %(len(hasSymbol)) )
            
            
        ## save expression for each impact
        
        if reLoadParams:
            loadParams() # re-load lca-algebraic parameters from AB-dev
                
        ## Loop on all combinations, and save impact equation & lambdas
        for c in self.CombinationsMatrices.keys(): # c is number of scenario, 1-9
            X_NS = self.CombinationsMatrices[c]['X_NS']
            iS_NS = EFs*X_NS
            
            # messyObject is an array with impact for every scenario and activity in A nonsquare techmatrix
            messyObject = EFs * diag(*X_NS)
            
            # basic contribution analysis cf. section 2.3 
            
            self.CombinationsMatrices[c]['iS_NS'] = iS_NS
            ## lambdify expression, ready lca_algebraic.stats functions
            self.CombinationsMatrices[c]['lambdas'] = {}
            self.CombinationsMatrices[c]['messyObject'] = {}
            self.CombinationsMatrices[c]['params_in_use'] = {}
            self.CombinationsMatrices[c]['expr'] = {}
            for i in range(iS_NS.shape[0]):
                # in-use symbols
                expr = iS_NS[i,:][0]
                expr_symbols = [str(k) for k in expr.free_symbols]
                # params_in_use need to have the correct name for enumeration Parameters
                params_in_use = {}
                for param in lca._param_registry().values():
                    for name in param.names(): # one 1 name if not enumParam, several if enumParam
                        if name in expr_symbols:
                            params_in_use[param.name] = param  # get the name of the enumParam or Param
                
            self.CombinationsMatrices[c]['lambdas'] = lca.LambdaWithParamNames(expr,
                                                    expanded_params=None, # is automatically created in the init via: _expand_param_names(self.params)
                                                    params=params_in_use,
                                                    sobols=None)
            
            self.CombinationsMatrices[c]['expr'] = expr
            self.CombinationsMatrices[c]['messyObject'] = messyObject
            self.CombinationsMatrices[c]['params_in_use'] = params_in_use

                
    def contributionAnalysis(self):
        '''
        This function only returns impact for every bg activity
        May need to change some stuff here so that activities that are not in the square A are not here...
        
        Function creates a new attribute .CombinationsMatrices[c]['lambdas_contrib']
        which contains for each studied combination c
        a vector 'lambdas_contrib' of dimension i x n [i = nb of impact categories, n = nb of activities in A_NS]
        with the impact arising from this processes, numerical values
        
            ! OBS: currently self.CombinationsMatrices[c]['lambdas_contrib'] = [] # initialised as a list > would only work for 1 impact category
            
        
        It is a basic contribution analysis.
        The algebraic vector is actually already calculated in the previous function, 
        and saved as self.CombinationsMatrices[c]['messyObject']
        
        Question: what is the while loop used for?
        
        '''
        for c in self.CombinationsMatrices.keys(): # c is number of scenario, 1-9
            
            self.CombinationsMatrices[c]['lambdas_contrib'] = [] # initialise the list
            
            j = 0 # counter for activities, each saved as an entry in lambdas_contrib2 array
            while j < len(self.CombinationsMatrices[c]['messyObject']): # for each activity and each scenario
                L1test = lca.LambdaWithParamNames(self.CombinationsMatrices[c]['messyObject'][j],
                        expanded_params=None, # is automatically created in the init via: _expand_param_names(self.params)
                        params=self.CombinationsMatrices[c]['params_in_use'],
                        sobols=None)
                # print(L1test)
                self.CombinationsMatrices[c]['lambdas_contrib'].append(postMultiLCAAlgebric2(IPCC, [L1test]))
                j += 1  
    
    def calcDeltas(self):
        self.Deltas = { } # to save everything in
        # based on systems_to_study, fu:s and lambdas -> save all deltas in dictionary
        # need to loop through fu:s (one at a time) and systems (pair-wise)
        
        k = 1 # counter for nbr of deltas
        for c in self.CombinationsMatrices.keys(): # c is number of scenario, 1-9
            j = c + 1 # counter for other scenarios, starting with the scenario after the current one
            while j <= len(self.CombinationsMatrices):
                if self.CombinationsMatrices[c]['fu'] == self.CombinationsMatrices[j]['fu']: # if fu:s are the same
                    expr2 = self.CombinationsMatrices[j]['expr'] - self.CombinationsMatrices[c]['expr']
                    paramsCombined = self.CombinationsMatrices[c]['params_in_use']
                    paramsCombined.update(self.CombinationsMatrices[j]['params_in_use'])
                    # should save both systems and the fu (one fu at a time)
                    self.Deltas[k] = {'fu': self.CombinationsMatrices[c]['fu'],
                                     's1': self.CombinationsMatrices[j]['system'],
                                     's2': self.CombinationsMatrices[c]['system'],
                                     'delta': lca.LambdaWithParamNames(expr2,
                                                    expanded_params=None, # is automatically created in the init via: _expand_param_names(self.params)
                                                    params=paramsCombined,
                                                    sobols=None)}
                    k += 1
                j += 1

    def caFinalVersion(self, col_acts, row_acts, mask, system):
        # ok so for real this time
        # based on fg cols and rows (act names) & a mask (fg activities in groups) -> return impacts for all the groups
        # returns, for every group: group name, impact w defalt values for params and impact w params in expr

        def SQ_to_NS_cols(i, system):
            '''
            i col nb in A_SQ, return col nb in A_NS
            '''
            return self.CombinationsMatrices[system]['old_col_nbs'][self.CombinationsMatrices[system]['A_rev_col_names'][i]]
        
        def findSqColNbr(act, system):
            # input: activity name (in paranthesis), system nbr
            # output: col nbr of activity (square A)
            col = [nbr for name, nbr in self.CombinationsMatrices[system]['A_col_names'].items() if name == act]
            return col
        
        def findRowByName(act):
            # input: name of activity (in paranthesis)
            # output: row nbr of activity (same no matter the scenario/A)
            row = [nbr for name, nbr in self.A_NS_rows.items() if name == act]
            return row
        
        foreground_cols = []
        foreground_rows = []
        
        for act in col_acts:
            colnbr = findSqColNbr(act, system)
            foreground_cols.append(colnbr[0])
        
        for act in row_acts:
            rownbr = findRowByName(act)
            foreground_rows.append(rownbr[0])
        
        current_system = self.CombinationsMatrices[system]
        A_sq = current_system['A']
        A_col = rev_dict(current_system['A_col_names'])
        A_row = rev_dict(self.A_NS_rows)
        
        I = eye(A_sq.shape[0]) # identity matrix of same size
        
        background_cols = [c for c,v in A_col.items() if c not in foreground_cols] # all the other rows
        background_rows = [r for r,v in A_row.items() if r not in foreground_rows] # all the other columns

        Y_sq = Y_from_dict(current_system['fu'], self.A_NS, self.A_NS_rows, self.A_NS_columns)
        
        # we cut the matrix into sub-matrices, of different dimensions
        A_ff = A_sq[foreground_rows, foreground_cols]
        Y_f = Y_sq[foreground_rows,:] 
        X_f = A_ff.inv('GE')*Y_f

        ## ESA: we can also do that with the rest of the system
        A_bf = A_sq[background_rows, foreground_cols] # all other rows
        A_bb = A_sq[background_rows, background_cols] # all other cols x all other cols
        Y_b = Y_sq[background_rows,:]
                
        X_bf = A_bb.inv('GE') * (-A_bf) * diag(*X_f) # background to foreground demand
        
        EF_f = SparseMatrix(1, A_ff.shape[1], 0) # subset of EFs for the background, as a Sympy Matrix
        for i,j in enumerate(foreground_cols):
            EF_f[i] = self.EFs[SQ_to_NS_cols(j, system)]
        
        EF_b = SparseMatrix(1, A_bb.shape[1], 0) # subset of EFs for the background, as a Sympy Matrix
        for i,j in enumerate(background_cols):
            EF_b[i] = self.EFs[SQ_to_NS_cols(j, system)]

        DIRECT_f = EF_f * diag(*X_f) # direct impact from foreground activities
        
        IMPACTS_b2f = EF_b * X_bf # returns a vector of dimension f with the impact as algebraic expression, can be evaluated numerically
            
        IMPACTS_f = DIRECT_f + IMPACTS_b2f # algebraic expression ! 
        
        IMPACTS_f = SparseMatrix(IMPACTS_f)
        
        IMPACTS_f_eval = evalSympy(IMPACTS_f) # added to handy functions to evaluate a sympy expression - see above the class
        
        # now: use mask to group the impacts
        
        def createMaskFromDict(mask, acts, fg_cols):
            # input: a dictionary w values that are names of acts
            # act = amount of fg activities (25 for now)
            # return a matrix 

            toReturn = SparseMatrix(len(mask.keys()), acts, 0)

            # find index in fg_cols

            i = 0 # counter for groups
            for k, v in mask.items(): # for every group in mask
                for act in v: # for every activity in mask group
                    for fgact in fg_cols: # for every activity in fg cols
                        if fgact == act: # if act in mask is same as current fg act
                            toReturn[i, fg_cols.index(fgact)] = 1
                i += 1
            return toReturn
        
        groupNames = mask.keys()
        
        M = createMaskFromDict(mask, len(IMPACTS_f), col_acts) # create Matrix for mask

        result1 = M * IMPACTS_f.T
        result2 = M * IMPACTS_f_eval.T
        
        toReturn1 = {}
        toReturn2 = {}
        
        for group, impact in zip(groupNames, result1):
            toReturn1[group] = impact
        
        for group, impact in zip(groupNames, result2):
            toReturn2[group] = impact
            
        
        return(toReturn1, toReturn2)
    

## End of the class

# %% [markdown]
# ## Project initialisation

# %% [markdown]
# ### Project name, final products, systems to study

# %%
prj = 'ThesisDeluxev3' # current project name: ThesisDeluxev3
if prj not in bw2.projects:
    print('Project does not exist, it will be created')
    bw2.projects.create_project(prj)
    bw2.projects.set_current(prj)
    if "biosphere3" not in bw2.databases:
        bw2.bw2setup()
else:
    print('The project exists, setting it as current project')
    bw2.projects.set_current(prj)

fg = 'MyThesisv2' # # project foreground database
if fg not in bw2.databases:
    print('Database %s not in databases, it will be created' %(fg))
    db = bw2.Database(fg)
    db.write({})
    
else:
    db = bw2.Database(fg)
    n = len(db)
    print('The database %s has %i entries' %(fg, n))
# Out:
# The project exists, setting it as current project
# The database MyThesisv2 has 29 entries

# %%
# SOUPs : heat, power, land use, biochar use
codes = ['soup-heat', 'soup-power', 'soup-land', 'soup-bc-use']
names = ['Heat production', 'Power production', 'Land use', 'Biochar use']
# i changed unit for soup-power to MJ instead of kWh 
units = ['megajoule', 'megajoule', 'tonne', 'cubic meter']

all_keys = [a.key for a in bw2.Database(fg)]

for i, c in enumerate(codes):
    if tuple((fg, c)) not in all_keys:
        a = newActivity(fg, # We define foreground activities in our own DB
                        names[i], # Name of the activity
                        units[i], # Unit
                        exchanges= {},
                        code=c #code of the activity
                       )
        a.addExchanges({a :  1}) # type = production for that exchange, because input is self
    else:
        print('Activity %s already present in database. Not over-written' %(names[i]))
# Out:
# Activity Heat production already present in database. Not over-written
# Activity Power production already present in database. Not over-written
# Activity Land use already present in database. Not over-written
# Activity Biochar use already present in database. Not over-written

# %%
# MOPs (systems to study): Biochar, BECCS, CHP
codes = ['mop-CHP', 'mop-BECCS', 'mop-BIOCHAR']
names = ['CHP', 'BECCS', 'Biochar']
units = ['', '', '', '']

all_keys = [a.key for a in bw2.Database(fg)]

for i, c in enumerate(codes):
    if tuple((fg, c)) not in all_keys:
        a = newActivity(fg, # We define foreground activities in our own DB
                        names[i], # Name of the activity
                        units[i], # Unit
                        exchanges= {},
                        code=c #code of the activity
                       )
    else:
        print('Activity %s already present in database. Not over-written' %(names[i]))
# Out:
# Activity CHP already present in database. Not over-written
# Activity BECCS already present in database. Not over-written
# Activity Biochar already present in database. Not over-written

# %% [markdown]
# ## Calculation set-up

# %%
bw2.projects.set_current(prj)

# %% [markdown]
# ### Systems studied, functional units, impact categories

# %%
# start with defining a list for all 3 scenarios
systems_to_study = [(fg, 'mop-CHP'), # ScenarioCHP
                    (fg, 'mop-BIOCHAR'), #ScenarioBiochar
                    (fg, 'mop-BECCS'), #ScenarioBECCS
                   ]     

# define FU:s and put them in a list
# only single output fu:s for products produced by all systems since any other combination will be equal to them anyway
fu1 = {(fg, 'soup-heat'):1000} #fu1 demands 1 GJ heat (1000 MJ)
fu2 = {(fg, 'soup-power'):3600} #fu2 demands 1 MWh electricity only (1 kWh = 3.6 MJ -> 1 MWh = 3600)
fu3 = {(fg, 'soup-land'):1} # fu3 demands land only (1 tonne)

fus_to_study = [fu1, fu2, fu3]

# list of the final products, i.e. produced by the studied systems or demanded in the fu
final_products = [(fg, 'soup-heat'), (fg, 'soup-power'), (fg, 'soup-land'), (fg, 'soup-bc-use')]

# Impact categories studied, as a list
## IPCC method GWP100
IPCC = [method for method in bw2.methods if "IPCC 2013" in str(method) 
        and "GWP 100" in str(method) 
        and "LT" not in str(method)
        and "V1" not in str(method)]
IPCC_unit = [r'kg $CO_2$-eq']

# %% [markdown]
# ### Calculate for first 3 FUs

# %%
# Initialise the comparative LCA
bioenergy = CLCA(FunctionalUnits=fus_to_study,
                 SystemsCompared=systems_to_study,
                 FinalProducts=final_products,
                 ImpactCategories=IPCC)

# %%
bioenergy.gen_matrices() # calculates the non-square technosphere/biosphere matrices

# %%
bioenergy.calc_inventories() # calculates for all fus, and systems, the inventories (X vector)

# %%
bioenergy.calc_ImpactEquation() # calculates the impact of all systems, with generic EF for each activity

# %%
bioenergy.calc_specificImpact(reLoadParams = True) # calculates the impact of all systems, with actual numerical values for each background activities
# reLoadParams=True >> will reload the parameters from bw2 as LCA algebraic parameters, to create the lambda functions
# may over-ride parameters

# i have no idea why stuff is being printed? maybe there's a print left in a .py file somewhere?
# Out:
# Activity '15f7791d9760433bb52788898d52821f#DirectEmissions' was already in 'DirectEmissions'. Overwriting it
# Activity '6392a42500ec45dc9df2c24b908a29b8#DirectEmissions' was already in 'DirectEmissions'. Overwriting it
# Activity '80c4125c3f7e43a79db435d0f84b7279#DirectEmissions' was already in 'DirectEmissions'. Overwriting it
# Activity '831f89cad404425b83cf7289bece3f0c#DirectEmissions' was already in 'DirectEmissions'. Overwriting it
# Activity 'c8f96f3ff68a473a81bd8bd2fdf6f5a3#DirectEmissions' was already in 'DirectEmissions'. Overwriting it
# 2
# elec_switch_param
# heat_switch_param

# %%
# impact for every activity w direct impact for every scenario
# results saved in bioenergy.CombinationsMatrices[i]['lambdas_contrib'], i = nbr of scenario
bioenergy.contributionAnalysis()
# Out:
# Required param 'TransportDistanceBiomass' was missing, replacing by default value : 500.0
# Required param 'LHVWoodchips' was missing, replacing by default value : 18.0
# Required param 'PowerEfficiency' was missing, replacing by default value : 0.33
# Required param 'ThermalEfficiency' was missing, replacing by default value : 0.7
# Required param 'elec_switch_param' was missing, replacing by default value : elecWindpower
# Required param 'TransportDistanceBiomass' was missing, replacing by default value : 500.0
# Required param 'LHVWoodchips' was missing, replacing by default value : 18.0
# Required param 'PowerEfficiency' was missing, replacing by default value : 0.33
# Required param 'ThermalEfficiency' was missing, replacing by default value : 0.7
# Required param 'elec_switch_param' was missing, replacing by default value : elecWindpower
# Required param 'TransportDistanceBiomass' was missing, replacing by default value : 500.0
# ...

# %%
bioenergy.calcDeltas()

# %% [markdown]
# ### Alternative Calculation - CDR as FU

# %% [markdown]
# OBS I'm gonna name this <b>bioenergyCDR</b> so that we can manage both scenarios at the same time

# %%
bw2.projects.set_current(prj)

# %% [markdown]
# ### Systems studied, functional units, impact categories

# %%
systems_to_study = [(fg, 'mop-BIOCHAR'), #ScenarioBiochar
                    (fg, 'mop-BECCS'), #ScenarioBECCS
                   ]     

systems_not_to_study = [(fg, 'mop-CHP')] # CHP - just so that it will be removed from matrix

# define FU:s and put them in a list
# we have an activity for CO2 seq - ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c')
fu1 = {(fg, '831f89cad404425b83cf7289bece3f0c'):1} #fu1 demands 1 kg CO2 seq
fus_to_study = [fu1]

# list of the final products, i.e. produced by the studied systems or demanded in the fu -> added CO2 seq
final_products = [(fg, 'soup-heat'), (fg, 'soup-power'), (fg, 'soup-land'), (fg, 'soup-bc-use'), (fg, '831f89cad404425b83cf7289bece3f0c')]

# Impact categories studied, as a list
## IPCC method GWP100
IPCC = [method for method in bw2.methods if "IPCC 2013" in str(method) 
        and "GWP 100" in str(method) 
        and "LT" not in str(method)
        and "V1" not in str(method)]
IPCC_unit = [r'kg $CO_2$-eq']

# %% [markdown]
# ### Calculate for CDR FU

# %%
# Initialise the comparative LCA
bioenergyCDR = CLCA(FunctionalUnits=fus_to_study,
                 SystemsCompared=systems_to_study,
                 SystemsNotCompared=systems_not_to_study,
                 FinalProducts=final_products,
                 ImpactCategories=IPCC)

# %%
bioenergyCDR.gen_matrices() # calculates the non-square technosphere/biosphere matrices

# %%
bioenergyCDR.calc_inventories() # calculates for all fus, and systems, the inventories (X vector)

# %%
bioenergyCDR.calc_ImpactEquation() # calculates the impact of all systems, with generic EF for each activity

# %%
bioenergyCDR.calc_specificImpact(reLoadParams = True) # calculates the impact of all systems, with actual numerical values for each background activities
# reLoadParams=True >> will reload the parameters from bw2 as LCA algebraic parameters, to create the lambda functions
# may over-ride parameters
# Out:
# Activity '15f7791d9760433bb52788898d52821f#DirectEmissions' was already in 'DirectEmissions'. Overwriting it
# Activity '6392a42500ec45dc9df2c24b908a29b8#DirectEmissions' was already in 'DirectEmissions'. Overwriting it
# Activity '80c4125c3f7e43a79db435d0f84b7279#DirectEmissions' was already in 'DirectEmissions'. Overwriting it
# Activity '831f89cad404425b83cf7289bece3f0c#DirectEmissions' was already in 'DirectEmissions'. Overwriting it
# Activity 'c8f96f3ff68a473a81bd8bd2fdf6f5a3#DirectEmissions' was already in 'DirectEmissions'. Overwriting it
# Param BiocharYield was already defined : overriding
# Param CO2PipelineLeakage was already defined : overriding
# Param CO2LongtermStorageLeakage was already defined : overriding
# Param TransportDistanceBiomass was already defined : overriding
# Param TransportDistanceBiochar was already defined : overriding
# Param ElectricityRatio was already defined : overriding
# Param CarbonCapturePercentage was already defined : overriding
# ...

# %%
# impact for every activity w direct impact for every scenario
# results saved in bioenergy.CombinationsMatrices[i]['lambdas_contrib'], i = nbr of scenario
bioenergyCDR.contributionAnalysis()
# Out:
# Required param 'BiocharYield' was missing, replacing by default value : 0.285
# Required param 'TransportDistanceBiomass' was missing, replacing by default value : 500.0
# Required param 'TransportDistanceBiochar' was missing, replacing by default value : 250.0
# Required param 'ElectricityRatio' was missing, replacing by default value : 0.30000000000000004
# Required param 'BiocharDecay' was missing, replacing by default value : 0.3
# Required param 'LHVWoodchips' was missing, replacing by default value : 18.0
# Required param 'TransportDistanceSoil' was missing, replacing by default value : 100.0
# Required param 'elec_switch_param' was missing, replacing by default value : elecWindpower
# Required param 'heat_switch_param' was missing, replacing by default value : heatWoodchips
# Required param 'BiocharYield' was missing, replacing by default value : 0.285
# Required param 'TransportDistanceBiomass' was missing, replacing by default value : 500.0
# ...

# %%
bioenergyCDR.calcDeltas()

# %% [markdown]
# ### setup for analysis

# %% [markdown]
# #### define lambdas & deltas

# %% [markdown]
# Key for CDR:
#
# L1: BC
#
# L2: BECCS
#
# D: BECCS - BC

# %%
# define lamdbas & deltas & load dataframes from excelfiles
L1 = bioenergy.CombinationsMatrices[1]['lambdas']
L2 = bioenergy.CombinationsMatrices[2]['lambdas']
L3 = bioenergy.CombinationsMatrices[3]['lambdas']
L4 = bioenergy.CombinationsMatrices[4]['lambdas']
L5 = bioenergy.CombinationsMatrices[5]['lambdas']
L6 = bioenergy.CombinationsMatrices[6]['lambdas']
L7 = bioenergy.CombinationsMatrices[7]['lambdas']
L8 = bioenergy.CombinationsMatrices[8]['lambdas']
L9 = bioenergy.CombinationsMatrices[9]['lambdas']

# from class: D1 = L2-L1, D2 = L3-L1, D3 = L3-L2 etc
# (i changed it so that deltas involving CHP are defined as (other system - CHP) instead of other way around)
D1 = bioenergy.Deltas[1]['delta']
D2 = bioenergy.Deltas[2]['delta']
D3 = bioenergy.Deltas[3]['delta']
D4 = bioenergy.Deltas[4]['delta']
D5 = bioenergy.Deltas[5]['delta']
D6 = bioenergy.Deltas[6]['delta']
D7 = bioenergy.Deltas[7]['delta']
D8 = bioenergy.Deltas[8]['delta']
D9 = bioenergy.Deltas[9]['delta']

L1_CDR = bioenergyCDR.CombinationsMatrices[1]['lambdas']
L2_CDR = bioenergyCDR.CombinationsMatrices[2]['lambdas']
D_CDR = bioenergyCDR.Deltas[1]['delta']

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### contribution analysis

# %% [markdown]
# #### set up groups

# %%
foreground_cols1 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-power'), ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '25430fddc3ba47f9be5b027972c8cdc7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', 'mop-CHP')]
foreground_rows1 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-power'), ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '25430fddc3ba47f9be5b027972c8cdc7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', 'soup-heat')]

mask1 = {
    'Supply chain': [('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '25430fddc3ba47f9be5b027972c8cdc7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b')],
    'System expansion, electricity': [('MyThesisv2', 'soup-power')],
    'System expansion, land use': [('MyThesisv2', 'soup-land')]}

result1params, result1clean = bioenergy.caFinalVersion(foreground_cols1, foreground_rows1, mask1, 1)

foreground_cols2 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-power'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'),
                   ('MyThesisv2', 'soup-bc-use'), ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6'),
                   ('MyThesisv2', 'mop-BIOCHAR')]
foreground_rows2 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-power'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'),
                   ('MyThesisv2', 'soup-bc-use'), ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6'),
                   ('MyThesisv2', 'soup-heat')]

mask2 = {
    'Supply chain': [('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'),
                   ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6')],
    'System expansion, electricity': [('MyThesisv2', 'soup-power')],
    'System expansion, land use': [('MyThesisv2', 'soup-land')],
    'System expansion, biochar usage': [('MyThesisv2', 'soup-bc-use')],
    'CDR': [('MyThesisv2', '831f89cad404425b83cf7289bece3f0c')]}

result2params, result2clean = bioenergy.caFinalVersion(foreground_cols2, foreground_rows2, mask2, 2)

foreground_cols3 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-power'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', 'f185fdedfa0b4a7e872dec61ddd95e39'),
                   ('MyThesisv2', '686c4e607be64d70933020f1a46166f7'),
                   ('MyThesisv2', '9584e3e36e1e4d478d3780df60dc0f5d'), ('MyThesisv2', 'mop-BECCS')]
foreground_rows3 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-power'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', 'f185fdedfa0b4a7e872dec61ddd95e39'),
                   ('MyThesisv2', '686c4e607be64d70933020f1a46166f7'),
                   ('MyThesisv2', '9584e3e36e1e4d478d3780df60dc0f5d'), ('MyThesisv2', 'soup-heat')]

mask3 = {
    'Supply chain': [('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'), ('MyThesisv2', '9584e3e36e1e4d478d3780df60dc0f5d'), ('MyThesisv2', 'f185fdedfa0b4a7e872dec61ddd95e39'),
                    ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '686c4e607be64d70933020f1a46166f7')],
    'System expansion, electricity': [('MyThesisv2', 'soup-power')],
    'System expansion, land use': [('MyThesisv2', 'soup-land')],
    'CDR': [('MyThesisv2', '831f89cad404425b83cf7289bece3f0c')]}

result3params, result3clean, = bioenergy.caFinalVersion(foreground_cols3, foreground_rows3, mask3, 3)

foreground_cols4 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '25430fddc3ba47f9be5b027972c8cdc7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', 'mop-CHP')]
foreground_rows4 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '25430fddc3ba47f9be5b027972c8cdc7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', 'soup-power')]

mask4 = {
    'Supply chain': [('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '25430fddc3ba47f9be5b027972c8cdc7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b')],
    'System expansion, heat': [('MyThesisv2', 'soup-heat')],
    'System expansion, land use': [('MyThesisv2', 'soup-land')]}

result4params, result4clean = bioenergy.caFinalVersion(foreground_cols4, foreground_rows4, mask4, 4)

foreground_cols5 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'),
                   ('MyThesisv2', 'soup-bc-use'), ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6'),
                   ('MyThesisv2', 'mop-BIOCHAR')]
foreground_rows5 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'),
                   ('MyThesisv2', 'soup-bc-use'), ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6'),
                   ('MyThesisv2', 'soup-power')]

mask5 = {
    'Supply chain': [('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'), ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6')],
    'System expansion, heat': [('MyThesisv2', 'soup-heat')],
    'System expansion, land use': [('MyThesisv2', 'soup-land')],
    'System expansion, biochar usage': [('MyThesisv2', 'soup-bc-use')],
    'CDR': [('MyThesisv2', '831f89cad404425b83cf7289bece3f0c')]}

result5params, result5clean = bioenergy.caFinalVersion(foreground_cols5, foreground_rows5, mask5, 5)

foreground_cols6 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'),
                   ('MyThesisv2', '686c4e607be64d70933020f1a46166f7'),
                   ('MyThesisv2', 'mop-BECCS')]
foreground_rows6 = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'),
                   ('MyThesisv2', '686c4e607be64d70933020f1a46166f7'),
                   ('MyThesisv2', 'soup-power')]

mask6 = {
    'Supply chain': [('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '686c4e607be64d70933020f1a46166f7')],
    'System expansion, heat': [('MyThesisv2', 'soup-heat')],
    'System expansion, land use': [('MyThesisv2', 'soup-land')],
    'CDR': [('MyThesisv2', '831f89cad404425b83cf7289bece3f0c')]}

result6params, result6clean = bioenergy.caFinalVersion(foreground_cols6, foreground_rows6, mask6, 6)

foreground_cols7 = [('MyThesisv2', 'soup-power'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '25430fddc3ba47f9be5b027972c8cdc7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', 'mop-CHP')]
foreground_rows7 = [('MyThesisv2', 'soup-power'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '25430fddc3ba47f9be5b027972c8cdc7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', 'soup-land')]

mask7 = {
    'Supply chain': [('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '25430fddc3ba47f9be5b027972c8cdc7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b')],
    'System expansion, heat': [('MyThesisv2', 'soup-heat')],
    'System expansion, electricity': [('MyThesisv2', 'soup-power')]}

result7params, result7clean = bioenergy.caFinalVersion(foreground_cols7, foreground_rows7, mask7, 7)

foreground_cols8 = [('MyThesisv2', 'soup-power'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'),
                   ('MyThesisv2', 'soup-bc-use'), ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6'),
                   ('MyThesisv2', 'mop-BIOCHAR')]
foreground_rows8 = [('MyThesisv2', 'soup-power'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'),
                   ('MyThesisv2', 'soup-bc-use'), ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6'),
                   ('MyThesisv2', 'soup-land')]

mask8 = {
    'Supply chain': [('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'), ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6')],
    'System expansion, heat': [('MyThesisv2', 'soup-heat')],
    'System expansion, electricity': [('MyThesisv2', 'soup-power')],
    'System expansion, biochar usage': [('MyThesisv2', 'soup-bc-use')],
    'CDR': [('MyThesisv2', '831f89cad404425b83cf7289bece3f0c')]}

result8params, result8clean = bioenergy.caFinalVersion(foreground_cols8, foreground_rows8, mask8, 8)

foreground_cols9 = [('MyThesisv2', 'soup-power'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'),
                   ('MyThesisv2', '686c4e607be64d70933020f1a46166f7'),
                   ('MyThesisv2', 'mop-BECCS')]
foreground_rows9 = [('MyThesisv2', 'soup-power'), ('MyThesisv2', 'soup-heat'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'),
                   ('MyThesisv2', '686c4e607be64d70933020f1a46166f7'),
                   ('MyThesisv2', 'soup-land')]

mask9 = {
    'Supply chain': [('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '686c4e607be64d70933020f1a46166f7')],
    'System expansion, heat': [('MyThesisv2', 'soup-heat')],
    'System expansion, electricity': [('MyThesisv2', 'soup-power')],
    'CDR': [('MyThesisv2', '831f89cad404425b83cf7289bece3f0c')]}

result9params, result9clean = bioenergy.caFinalVersion(foreground_cols9, foreground_rows9, mask9, 9)

foreground_cols1_CDR = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-power'), ('MyThesisv2', 'soup-heat'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'),
                   ('MyThesisv2', 'soup-bc-use'), ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6'),
                   ('MyThesisv2', 'mop-BIOCHAR')]
foreground_rows1_CDR = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-power'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'),
                   ('MyThesisv2', 'soup-bc-use'), ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6'),
                   ('MyThesisv2', 'soup-heat')]

mask1_CDR = {
    'Supply chain': [('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', 'f223f9b358ef47a8a204a05f0cadafa0'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '1840e94cca3348f8a3ee7d953f03cae3'), ('MyThesisv2', '4c6b2e9520bc4c4ab1db70962117fcc6')],
    'System expansion, electricity': [('MyThesisv2', 'soup-power')],
    'System expansion, land use': [('MyThesisv2', 'soup-land')],
    'System expansion, heat': [('MyThesisv2', 'soup-heat')],
    'System expansion, biochar usage': [('MyThesisv2', 'soup-bc-use')]}

result1params_CDR, result1clean_CDR = bioenergyCDR.caFinalVersion(foreground_cols1_CDR, foreground_rows1_CDR, 
                                                                  mask1_CDR, 1)

foreground_cols2_CDR = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-power'), ('MyThesisv2', 'soup-heat'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'),
                   ('MyThesisv2', '686c4e607be64d70933020f1a46166f7'),
                   ('MyThesisv2', 'mop-BECCS')]
foreground_rows2_CDR = [('MyThesisv2', 'soup-land'), ('MyThesisv2', 'soup-power'), ('MyThesisv2', '831f89cad404425b83cf7289bece3f0c'),
                   ('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'),
                   ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'),
                   ('MyThesisv2', '686c4e607be64d70933020f1a46166f7'),
                   ('MyThesisv2', 'soup-heat')]

mask2_CDR = {
    'Supply chain': [('MyThesisv2', 'd8b28cc8dbce45778d56ad579e7843e3'), ('MyThesisv2', '3455744dd03842cab9018a032231fbf7'), ('MyThesisv2', '75526c0f5e044b8fa4bdfbde674f389b'), ('MyThesisv2', '686c4e607be64d70933020f1a46166f7')],
    'System expansion, electricity': [('MyThesisv2', 'soup-power')],
    'System expansion, land use': [('MyThesisv2', 'soup-land')],
    'System expansion, heat': [('MyThesisv2', 'soup-heat')]}

result2params_CDR, result2clean_CDR, = bioenergyCDR.caFinalVersion(foreground_cols2_CDR, foreground_rows2_CDR, 
                                                                   mask2_CDR, 2)
# Out:
# Required param 'LHVWoodchips' was missing, replacing by default value : 18.0
# Required param 'ThermalEfficiency' was missing, replacing by default value : 0.7
# Required param 'PowerEfficiency' was missing, replacing by default value : 0.33
# Required param 'ThermalEfficiency' was missing, replacing by default value : 0.7
# Required param 'elec_switch_param' was missing, replacing by default value : elecWindpower
# Required param 'LHVWoodchips' was missing, replacing by default value : 18.0
# Required param 'ThermalEfficiency' was missing, replacing by default value : 0.7
# Required param 'TransportDistanceBiomass' was missing, replacing by default value : 500.0
# Required param 'LHVWoodchips' was missing, replacing by default value : 18.0
# Required param 'ThermalEfficiency' was missing, replacing by default value : 0.7
# Required param 'elec_switch_param' was missing, replacing by default value : elecWindpower
# ...

# %% [markdown]
# #### check that it makes sense by comparing to old ca

# %%
# compare w first ca
s = sum(bioenergy.CombinationsMatrices[1]['lambdas_contrib'])
print(s)

s2 = 0
for k, v in result1clean.items():
    s2 = s2 + v
print(s2) 

s = sum(bioenergy.CombinationsMatrices[2]['lambdas_contrib'])
print(s)

s2 = 0
for k, v in result2clean.items():
    s2 = s2 + v
print(s2)

s = sum(bioenergy.CombinationsMatrices[3]['lambdas_contrib'])
print(s)

s2 = 0
for k, v in result3clean.items():
    s2 = s2 + v
print(s2) 

s = sum(bioenergy.CombinationsMatrices[4]['lambdas_contrib'])
print(s)

s2 = 0
for k, v in result4clean.items():
    s2 = s2 + v
print(s2)

s = sum(bioenergy.CombinationsMatrices[5]['lambdas_contrib'])
print(s)

s2 = 0
for k, v in result5clean.items():
    s2 = s2 + v
print(s2) 

s = sum(bioenergy.CombinationsMatrices[6]['lambdas_contrib'])
print(s)

s2 = 0
for k, v in result6clean.items():
    s2 = s2 + v
print(s2)

s = sum(bioenergy.CombinationsMatrices[7]['lambdas_contrib'])
print(s)

s2 = 0
for k, v in result7clean.items():
    s2 = s2 + v
print(s2)

s = sum(bioenergy.CombinationsMatrices[8]['lambdas_contrib'])
print(s)

s2 = 0
for k, v in result8clean.items():
    s2 = s2 + v
print(s2) 

s = sum(bioenergy.CombinationsMatrices[9]['lambdas_contrib'])
print(s)

s2 = 0
for k, v in result9clean.items():
    s2 = s2 + v
print(s2)

s = sum(bioenergyCDR.CombinationsMatrices[1]['lambdas_contrib'])
print(s)

s2 = 0
for k, v in result1clean_CDR.items():
    s2 = s2 + v
print(s2)

s = sum(bioenergyCDR.CombinationsMatrices[2]['lambdas_contrib'])
print(s)

s2 = 0
for k, v in result2clean_CDR.items():
    s2 = s2 + v
print(s2)
# Out:
# 16.19263062384877
# 16.1926306238488
# -101.15318656921033
# -101.153186569210
# -80.34363909306778
# -80.3436390930678
# 51.24135487278663
# 51.2413548727866
# -930.8745803151772
# -930.874580315176
# -2199.6658381824195
# -2199.66583818242
# -29.882667643404574
# -29.8826676434045
# -903.1990955394011
# -903.199095539398
# -1517.9360596713277
# -1517.93605967133
# -0.39114677980075263
# -0.391146779800752
# 0.04489415386852824
# 0.0448941538685281

# %% [markdown]
# #### set up for distributions

# %%
# create lambdas for every case and group so we can do stuff
case1L1 = createLambda(result1params['Supply chain'])
case1L2 = createLambda(result1params['System expansion, electricity'])
case1L3 = createLambda(result1params['System expansion, land use'])

case2L1 = createLambda(result2params['Supply chain'])
case2L2 = createLambda(result2params['System expansion, electricity'])
case2L3 = createLambda(result2params['System expansion, land use'])
case2L4 = createLambda(result2params['System expansion, biochar usage'])
case2L5 = createLambda(result2params['CDR'])

case3L1 = createLambda(result3params['Supply chain'])
case3L2 = createLambda(result3params['System expansion, electricity'])
case3L3 = createLambda(result3params['System expansion, land use'])
case3L4 = createLambda(result3params['CDR'])
                                     
case4L1 = createLambda(result4params['Supply chain'])
case4L2 = createLambda(result4params['System expansion, heat'])
case4L3 = createLambda(result4params['System expansion, land use'])

case5L1 = createLambda(result5params['Supply chain'])
case5L2 = createLambda(result5params['System expansion, heat'])
case5L3 = createLambda(result5params['System expansion, land use'])
case5L4 = createLambda(result5params['System expansion, biochar usage'])
case5L5 = createLambda(result5params['CDR'])

case6L1 = createLambda(result6params['Supply chain'])
case6L2 = createLambda(result6params['System expansion, heat'])
case6L3 = createLambda(result6params['System expansion, land use'])
case6L4 = createLambda(result6params['CDR'])

case7L1 = createLambda(result7params['Supply chain'])
case7L2 = createLambda(result7params['System expansion, heat'])
case7L3 = createLambda(result7params['System expansion, electricity'])

case8L1 = createLambda(result8params['Supply chain'])
case8L2 = createLambda(result8params['System expansion, heat'])
case8L3 = createLambda(result8params['System expansion, electricity'])
case8L4 = createLambda(result8params['System expansion, biochar usage'])
case8L5 = createLambda(result8params['CDR'])

case9L1 = createLambda(result9params['Supply chain'])
case9L2 = createLambda(result9params['System expansion, heat'])
case9L3 = createLambda(result9params['System expansion, electricity'])
case9L4 = createLambda(result9params['CDR'])

case1L1_CDR = createLambda(result1params_CDR['Supply chain'])
case1L2_CDR = createLambda(result1params_CDR['System expansion, electricity'])
case1L3_CDR = createLambda(result1params_CDR['System expansion, land use'])
case1L4_CDR = createLambda(result1params_CDR['System expansion, heat'])
case1L5_CDR = createLambda(result1params_CDR['System expansion, biochar usage'])

case2L1_CDR = createLambda(result2params_CDR['Supply chain'])
case2L2_CDR = createLambda(result2params_CDR['System expansion, electricity'])
case2L3_CDR = createLambda(result2params_CDR['System expansion, land use'])
case2L4_CDR = createLambda(result2params_CDR['System expansion, heat'])

# %%
from lca_algebraic.stats import _stochastics
prob, params, Y =_stochastics([L1], IPCC, n=10000)

# create df:s for every case&group
from lca_algebraic.stats import _compute_stochastics
Y1 = _compute_stochastics([case1L1], IPCC, params)
Y12 = _compute_stochastics([case1L2], IPCC, params)
Y13 = _compute_stochastics([case1L3], IPCC, params)
Y1.rename(columns ={'climate change - GWP 100a': 'Supply chain'}, inplace = True)
Y1['System expansion, electricity'] = Y12.values
Y1['System expansion, land use'] = Y13.values

Y2 = _compute_stochastics([case2L1], IPCC, params)
Y22 = _compute_stochastics([case2L2], IPCC, params)
Y23 = _compute_stochastics([case2L3], IPCC, params)
Y24 = _compute_stochastics([case2L4], IPCC, params)
Y25 = _compute_stochastics([case2L5], IPCC, params)
Y2.rename(columns ={'climate change - GWP 100a': 'Supply chain'}, inplace = True)
Y2['System expansion, electricity'] = Y22.values
Y2['System expansion, land use'] = Y23.values
Y2['System expansion, biochar usage'] = Y24.values
Y2['Carbon sequestration'] = Y25.values

Y3 = _compute_stochastics([case3L1], IPCC, params)
Y32 = _compute_stochastics([case3L2], IPCC, params)
Y33 = _compute_stochastics([case3L3], IPCC, params)
Y34 = _compute_stochastics([case3L4], IPCC, params)
Y3.rename(columns ={'climate change - GWP 100a': 'Supply chain'}, inplace = True)
Y3['System expansion, electricity'] = Y32.values
Y3['System expansion, land use'] = Y33.values
Y3['Carbon sequestration'] = Y34.values

Y4 = _compute_stochastics([case4L1], IPCC, params)
Y42 = _compute_stochastics([case4L2], IPCC, params)
Y43 = _compute_stochastics([case4L3], IPCC, params)
Y4.rename(columns ={'climate change - GWP 100a': 'Supply chain'}, inplace = True)
Y4['System expansion, heat'] = Y42.values
Y4['System expansion, land use'] = Y43.values

Y5 = _compute_stochastics([case5L1], IPCC, params)
Y52 = _compute_stochastics([case5L2], IPCC, params)
Y53 = _compute_stochastics([case5L3], IPCC, params)
Y54 = _compute_stochastics([case5L4], IPCC, params)
Y55 = _compute_stochastics([case5L5], IPCC, params)
Y5.rename(columns ={'climate change - GWP 100a': 'Supply chain'}, inplace = True)
Y5['System expansion, heat'] = Y52.values
Y5['System expansion, land use'] = Y53.values
Y5['System expansion, biochar usage'] = Y54.values
Y5['Carbon sequestration'] = Y55.values

Y6 = _compute_stochastics([case6L1], IPCC, params)
Y62 = _compute_stochastics([case6L2], IPCC, params)
Y63 = _compute_stochastics([case6L3], IPCC, params)
Y64 = _compute_stochastics([case6L4], IPCC, params)
Y6.rename(columns ={'climate change - GWP 100a': 'Supply chain'}, inplace = True)
Y6['System expansion, heat'] = Y62.values
Y6['System expansion, land use'] = Y63.values
Y6['Carbon sequestration'] = Y64.values

Y7 = _compute_stochastics([case7L1], IPCC, params)
Y72 = _compute_stochastics([case7L2], IPCC, params)
Y73 = _compute_stochastics([case7L3], IPCC, params)
Y7.rename(columns ={'climate change - GWP 100a': 'Supply chain'}, inplace = True)
Y7['System expansion, heat'] = Y72.values
Y7['System expansion, electricity'] = Y73.values

Y8 = _compute_stochastics([case8L1], IPCC, params)
Y82 = _compute_stochastics([case8L2], IPCC, params)
Y83 = _compute_stochastics([case8L3], IPCC, params)
Y84 = _compute_stochastics([case8L4], IPCC, params)
Y85 = _compute_stochastics([case8L5], IPCC, params)
Y8.rename(columns ={'climate change - GWP 100a': 'Supply chain'}, inplace = True)
Y8['System expansion, heat'] = Y82.values
Y8['System expansion, electricity'] = Y83.values
Y8['System expansion, biochar usage'] = Y84.values
Y8['Carbon sequestration'] = Y85.values

Y9 = _compute_stochastics([case9L1], IPCC, params)
Y92 = _compute_stochastics([case9L2], IPCC, params)
Y93 = _compute_stochastics([case9L3], IPCC, params)
Y94 = _compute_stochastics([case9L4], IPCC, params)
Y9.rename(columns ={'climate change - GWP 100a': 'Supply chain'}, inplace = True)
Y9['System expansion, heat'] = Y92.values
Y9['System expansion, electricity'] = Y93.values
Y9['Carbon sequestration'] = Y94.values

Y1_CDR = _compute_stochastics([case1L1_CDR], IPCC, params)
Y12_CDR = _compute_stochastics([case1L2_CDR], IPCC, params)
Y13_CDR = _compute_stochastics([case1L3_CDR], IPCC, params)
Y14_CDR = _compute_stochastics([case1L4_CDR], IPCC, params)
Y15_CDR = _compute_stochastics([case1L5_CDR], IPCC, params)

Y1_CDR.rename(columns ={'climate change - GWP 100a': 'Supply chain'}, inplace = True)
Y1_CDR['System expansion, electricity'] = Y12_CDR.values
Y1_CDR['System expansion, land use'] = Y13_CDR.values
Y1_CDR['System expansion, heat'] = Y14_CDR.values
Y1_CDR['System expansion, biochar usage'] = Y15_CDR.values

Y2_CDR = _compute_stochastics([case2L1_CDR], IPCC, params)
Y22_CDR = _compute_stochastics([case2L2_CDR], IPCC, params)
Y23_CDR = _compute_stochastics([case2L3_CDR], IPCC, params)
Y24_CDR = _compute_stochastics([case2L4_CDR], IPCC, params)
Y2_CDR.rename(columns ={'climate change - GWP 100a': 'Supply chain'}, inplace = True)
Y2_CDR['System expansion, electricity'] = Y22_CDR.values
Y2_CDR['System expansion, land use'] = Y23_CDR.values
Y2_CDR['System expansion, heat'] = Y24_CDR.values
# Out:
# Generating samples ...
# C:\Users\lizn0001\Anaconda3\envs\bw2\lib\site-packages\SALib\sample\saltelli.py:94: UserWarning:
#         Convergence properties of the Sobol' sequence is only valid if
#         `N` (10000) is equal to `2^n`.
#
#   warnings.warn(msg)
# Transforming samples ...

# %% [markdown]
# #### plotting distrib final version

# %%
# add the missing categories with zeroes of last system so that we can easily plot the legend
Y2_CDR['System expansion, biochar usage']=0
Y2_CDR['Carbon sequestration']=0

# %%
listYs = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9, Y1_CDR, Y2_CDR]

# %%
# fix s.e. groups, in order to make legend shorter & change to sub (updated terminology)
for Y in listYs:
    if 'System expansion, biochar usage' in Y.columns:
        Y.rename(columns={'System expansion, biochar usage': "Sub. biochar usage"}, inplace = True)
    if 'System expansion, electricity' in Y.columns:    
        Y.rename(columns={'System expansion, electricity': "Sub. electricity"}, inplace = True)
    if 'System expansion, land use' in Y.columns:    
        Y.rename(columns={'System expansion, land use': "Sub. land use"}, inplace = True)
    if 'System expansion, heat' in Y.columns:    
        Y.rename(columns={'System expansion, heat': "Sub. heat"}, inplace = True)

# %% [markdown]
# https://matplotlib.org/3.1.1/tutorials/intermediate/gridspec.html
#
# Add one gridspec for each big row

# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# %%
def plotCombined(df, ax1, ax2, xlabel1 = 'xlabel1', xlabel2='xlabel2', ylabel1='ylabel1', ylabel2='ylabel2', nb_bins=200, color = sns.color_palette("Set1")):

    df_norm = df.div(df['Supply chain'], axis=0)

    df_tot = pd.DataFrame({'total':df.sum(axis=1)})

    # First graph: axl[0] or ax[0,0] > plot histogram
    # df_tot.plot(kind='hist', bins=3, ax=axl[0])
    n, bins, _ = ax1.hist(df_tot, bins=nb_bins) # plot histogram, as usual - 

    # n contains: the values of the histogram bins
    # bins contains: the edges of the bins
    # cf: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

    # apply the bins to the df_tot, either : pd.cut (equal-width) or pd.qcut (equal-size)
    df_tot['binned'], tmp = pd.cut(df_tot['total'], bins=nb_bins, labels=False, retbins=True)
    ## pd.cut should give the same distribution as the hist

    # we add these binns to the df with normalised contrib
    df_norm['binned'] = df_tot['binned']
    # googled: pandas average based on column value > first result !
    df_norm_grouped = df_norm.groupby('binned', as_index=True).mean() # as_index = True implies 'binned' is the index of the new df
    df_norm_grouped

    bins_continuous = np.zeros(0)
    df_norm_grouped_continuous = pd.DataFrame({})
    reps = 100

    for i in range(len(bins)-1):
        bins_continuous = np.concatenate( (bins_continuous, np.linspace(bins[i], bins[i+1], reps, endpoint=False)) )

        for col in df_norm_grouped.columns:
            df_norm_grouped_continuous[col] = df_norm_grouped[col].repeat(reps)

    for i in range(len(bins)-1):
        if i not in df_norm_grouped.index:
            salsa = pd.DataFrame(np.zeros((reps,len(df_norm_grouped_continuous.columns))),
                                 index=[i]*100,
                                 columns=df_norm_grouped_continuous.columns)
            df_norm_grouped_continuous = df_norm_grouped_continuous.append(salsa)

    df_norm_grouped_continuous.sort_index(inplace=True)

    # split neg & pos values
    df_norm_grouped_continuous_pos = df_norm_grouped_continuous[df_norm_grouped_continuous >= 0].fillna(0)
    df_norm_grouped_continuous_neg = df_norm_grouped_continuous[df_norm_grouped_continuous < 0].fillna(0)

    # Second graph: axl[1] or ax[1,0] > plot stacked bar binned ... in fact ... stacked area works
    ax2.stackplot(bins_continuous, 
                         [df_norm_grouped_continuous_pos.loc[:, col] for col in df_norm_grouped_continuous_pos.columns],
                         labels=df_norm_grouped_continuous_pos.columns,
                        colors=color)

    ax2.stackplot(bins_continuous, 
                         [df_norm_grouped_continuous_neg.loc[:, col] for col in df_norm_grouped_continuous_neg.columns],
                         #labels=Y1_norm_grouped_continuous.columns,
                        colors=color)

    #ax1.tick_params(axis='y', labelleft=False)
    ax1.tick_params(axis='x', labelleft=False)
    ax1.xaxis.set_ticklabels([])
    
    ax2.set_xlabel(xlabel2, fontsize = 12)
    ax2.set_ylabel(ylabel2, fontsize = 12)
    
    return fig, bins_continuous, df_norm_grouped_continuous

# %%
# 19*4 + 8*3 = 100 -> maybe still a bit too much space? ah I'm gonna go with it for now

gs1 = GridSpec(nrows = 3, ncols = 3, top = 1.00, bottom = 0.81)
gs2 = GridSpec(nrows = 3, ncols = 3, top = 0.73, bottom = 0.54)
gs3 = GridSpec(nrows = 3, ncols = 3, top = 0.46, bottom = 0.27)
gs4 = GridSpec(nrows = 3, ncols = 3, top = 0.19, bottom = 0.00)

fig = plt.figure(figsize=(10,12))

gs_list = [gs1, gs2, gs3, gs4]
axesL = []

for gs in gs_list: # for every gridspec
    for i in range(2): # and every row
        for j in range(3): # and every column
            if i == 0: 
                axesL.append(fig.add_subplot(gs[i,j])) # if small row (distrib)
            else:
                axesL.append(fig.add_subplot(gs[i:,j])) # if big row (ca)

axes = np.reshape(axesL, (8,3)).tolist()

listYs = [Y1, Y2, Y3, Y4, Y5, Y6, Y7, Y8, Y9, [], Y1_CDR, Y2_CDR]
colormapY1 = ['powderblue', 'palegoldenrod', 'lightseagreen']
colormapY2 = ['powderblue', 'palegoldenrod', 'lightseagreen', 'lightsalmon', 'darkgray']
colormapY3 = ['powderblue', 'palegoldenrod', 'lightseagreen', 'darkgray']
colormapY4 = ['powderblue', 'palevioletred', 'lightseagreen']
colormapY5 = ['powderblue', 'palevioletred', 'lightseagreen', 'lightsalmon', 'darkgray']
colormapY6 = ['powderblue', 'palevioletred', 'lightseagreen', 'darkgray']
colormapY7 = ['powderblue', 'palevioletred', 'palegoldenrod']
colormapY8 = ['powderblue', 'palevioletred', 'palegoldenrod', 'lightsalmon', 'darkgray']
colormapY9 = ['powderblue', 'palevioletred', 'palegoldenrod', 'darkgray']
Y1_CDRcolors = ['powderblue', 'palegoldenrod', 'lightseagreen', 'palevioletred', 'lightsalmon']
Y2_CDRcolors = ['powderblue', 'palegoldenrod', 'lightseagreen', 'palevioletred', 'lightsalmon', 'darkgray']
colorList = [colormapY1, colormapY2, colormapY3, colormapY4, colormapY5, colormapY6, colormapY7, colormapY8, colormapY9,
             colormapY1, Y1_CDRcolors, Y2_CDRcolors]

x_labels = ['CHP', 'Biochar', 'BECCS']*3
y_labels = ['Heat']*3+['Electricity']*3+['Biomass']*3

#xpos = [0.1, 0.5, 0.8]*3
#ypos = [0.9]*3+[0.7]*3, 
annot = ['a.', 'b.', 'c.', 'd.', 'e.', 'f.', 'g.', 'h.', 'i.', 'pass', 'j.', 'k.']

save_dfs = []
bins_df = pd.DataFrame()

for i, YY in enumerate(listYs):
    if i != 9:
        R = i // 3 # One row for each FU, 0-4
        fig, bins, df_test = plotCombined(YY, axesL[i+R*3], axesL[i+R*3+3],
                     xlabel1 = 'kg CO$_2$-eq', xlabel2 = 'kg CO$_2$-eq',
                     ylabel1 = 'Counts', ylabel2 = '',#'R$_{SC}$',
                     color = colorList[i])
        if i < 9: #just to keep indices in df neat & non-confusing
            bins_df[i] = bins
        else: 
            bins_df[i-1] = bins 
        save_dfs.append(df_test)
        axesL[i+R*3].annotate(text=annot[i], xy=(0.02, 0.75), 
                xycoords='axes fraction', fontsize = 14, ha='left', backgroundcolor = 'w',) #fontweight = 'bold')

axesL[18].set_visible(False)
axesL[21].set_visible(False)

handles, labels = axesL[23].get_legend_handles_labels()
lg = fig.legend(handles, labels, loc='lower left', ncol=1,fontsize=12,
                        borderaxespad=-0.0, bbox_to_anchor=(0.06, 0.05))

axesL[0].set_title('CHP', fontsize=16)
axesL[1].set_title('Biochar', fontsize=16)
axesL[2].set_title('BECCS', fontsize=16)

fig.text(0.336, 0.1, 'CO$_2$ seq', ha='center', va='center', rotation='vertical', fontsize=16)
fig.text(0.06, 0.36, 'Biomass usage', ha='center', va='center', rotation='vertical', fontsize=16)
fig.text(0.06, 0.63, 'Electricity', ha='center', va='center', rotation='vertical', fontsize=16)
fig.text(0.06, 0.90, 'Heat', ha='center', va='center', rotation='vertical', fontsize=16)
# Out:
# Text(0.06, 0.9, 'Heat')

# %%
#fig.savefig('allineonev3.3.png', dpi=1000, format='jpg', bbox_inches='tight')

# %%
def append_df_to_excel(filename, df, sheet_name='Sheet1', startrow=None,
                       truncate_sheet=True, 
                       **to_excel_kwargs):
    """
    Append a DataFrame [df] to existing Excel file [filename]
    into [sheet_name] Sheet.
    If [filename] doesn't exist, then this function will create it.

    Parameters:
      filename : File path or existing ExcelWriter
                 (Example: '/path/to/file.xlsx')
      df : dataframe to save to workbook
      sheet_name : Name of sheet which will contain DataFrame.
                   (default: 'Sheet1')
      startrow : upper left cell row to dump data frame.
                 Per default (startrow=None) calculate the last row
                 in the existing DF and write to the next row...
      truncate_sheet : truncate (remove and recreate) [sheet_name]
                       before writing DataFrame to Excel file
      to_excel_kwargs : arguments which will be passed to `DataFrame.to_excel()`
                        [can be dictionary]

    Returns: None

    (c) [MaxU](https://stackoverflow.com/users/5741205/maxu?tab=profile)
    """
    from openpyxl import load_workbook

    # ignore [engine] parameter if it was passed
    if 'engine' in to_excel_kwargs:
        to_excel_kwargs.pop('engine')

    writer = pd.ExcelWriter(filename, engine='openpyxl', mode='a')

    # Python 2.x: define [FileNotFoundError] exception if it doesn't exist 
    try:
        FileNotFoundError
    except NameError:
        FileNotFoundError = IOError


    try:
        # try to open an existing workbook
        writer.book = load_workbook(filename)
        
        # get the last row in the existing Excel sheet
        # if it was not specified explicitly
        if startrow is None and sheet_name in writer.book.sheetnames:
            startrow = writer.book[sheet_name].max_row

        # truncate sheet
        if truncate_sheet and sheet_name in writer.book.sheetnames:
            # re-set startrow
            startrow=0
            # index of [sheet_name] sheet
            idx = writer.book.sheetnames.index(sheet_name)
            # remove [sheet_name]
            writer.book.remove(writer.book.worksheets[idx])
            # create an empty sheet [sheet_name] using old index
            writer.book.create_sheet(sheet_name, idx)
        
        # copy existing sheets
        writer.sheets = {ws.title:ws for ws in writer.book.worksheets}
    except FileNotFoundError:
        # file does not exist yet, we will create it
        pass

    if startrow is None:
        startrow = 0

    # write out the new sheet
    df.to_excel(writer, sheet_name, startrow=startrow, **to_excel_kwargs)

    # save the workbook
    writer.save()

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\CA_bins.xlsx', 
                   bins_df, sheet_name='bins')

# %%
for i, df in enumerate(save_dfs):

    append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\CA_dfs.xlsx', 
                   df, sheet_name=str(i))

# %% [markdown]
# ### Global Sensitivity Analysis

# %% [markdown]
# #### get sobols

# %% [markdown]
# why are some still negative? reading https://salib.readthedocs.io/en/latest/api.html#sobol-sensitivity-analysis & checkgin their analyze/sobol file - ..?
#
# it seems though that all negative values are very small

# %%
from lca_algebraic.stats import incer_stochastic_matrix_L_return

# %%
sob1, problem1 = incer_stochastic_matrix_L_return([L1], IPCC, n=10000)
sob2, problem2 = incer_stochastic_matrix_L_return([L2], IPCC, n=10000)
sob3, problem3 = incer_stochastic_matrix_L_return([L3], IPCC, n=10000)
sob4, problem4 = incer_stochastic_matrix_L_return([L4], IPCC, n=10000)
sob5, problem5 = incer_stochastic_matrix_L_return([L5], IPCC, n=10000)
sob6, problem6 = incer_stochastic_matrix_L_return([L6], IPCC, n=10000)
sob7, problem7 = incer_stochastic_matrix_L_return([L7], IPCC, n=10000)
sob8, problem8 = incer_stochastic_matrix_L_return([L8], IPCC, n=10000)
sob9, problem9 = incer_stochastic_matrix_L_return([L9], IPCC, n=10000)
sob10, problem10 = incer_stochastic_matrix_L_return([L1_CDR], IPCC, n=10000)
sob11, problem11 = incer_stochastic_matrix_L_return([L2_CDR], IPCC, n=10000)
# Out:
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# ...

# %%
sob_df1 = pd.DataFrame()
sob_df2 = pd.DataFrame()
sob_df3 = pd.DataFrame()
sob_df4 = pd.DataFrame()
sob_df5 = pd.DataFrame()
sob_df6 = pd.DataFrame()
sob_df7 = pd.DataFrame()
sob_df8 = pd.DataFrame()
sob_df9 = pd.DataFrame()
sob_df10 = pd.DataFrame()
sob_df11 = pd.DataFrame()

# %%
sob_df1_round = pd.DataFrame()
sob_df2_round = pd.DataFrame()
sob_df3_round = pd.DataFrame()
sob_df4_round = pd.DataFrame()
sob_df5_round = pd.DataFrame()
sob_df6_round = pd.DataFrame()
sob_df7_round = pd.DataFrame()
sob_df8_round = pd.DataFrame()
sob_df9_round = pd.DataFrame()
sob_df10_round = pd.DataFrame()
sob_df11_round = pd.DataFrame()

# %%
sob_list = [sob1, sob2, sob3, sob4, sob5, sob6, sob7, sob8, sob9, sob10, sob11]
problem_list = [problem1, problem2, problem3, problem4, problem5, problem6, problem7, problem8, 
                problem9, problem10, problem11]
sob_df_list = [sob_df1, sob_df2, sob_df3, sob_df4, sob_df5, sob_df6, sob_df7, sob_df8, sob_df9,
              sob_df10, sob_df11]
sob_df_list_round = [sob_df1_round, sob_df2_round, sob_df3_round, sob_df4_round, sob_df5_round, 
            sob_df6_round, sob_df7_round, sob_df8_round, sob_df9_round, sob_df10_round, sob_df11_round]

# %%
for sob, names, df, df_round in zip(sob_list, problem_list, sob_df_list, sob_df_list_round): # for every scenario
    for s, name in zip(sob.s1, names['names']): # and every sobol & name
        df[name] = s
        df_round[name] = [str(round(s[0], 2))]

# %%
sob_df2_round
# Out:
#   BiocharDecay BiocharYield ElectricityRatio LHVWoodchips  \
# 0         0.04         0.23             0.16         -0.0
#
#   TransportDistanceBiochar TransportDistanceBiomass TransportDistanceSoil  \
# 0                      0.0                      0.0                   0.0
#
#   elec_switch_param
# 0              0.54

# %%
sob_df2
# Out:
#    BiocharDecay  BiocharYield  ElectricityRatio  LHVWoodchips  \
# 0      0.036805      0.225214          0.158471     -0.000004
#
#    TransportDistanceBiochar  TransportDistanceBiomass  TransportDistanceSoil  \
# 0                  0.000035                  0.001231               0.000006
#
#    elec_switch_param
# 0           0.539346

# %%
# next step: save to excel-files
for i, (df, df_round) in enumerate(zip(sob_df_list, sob_df_list_round)):
   #print(i)
    
    append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\sobols.xlsx', 
                   df, sheet_name=str(i))
                       
    append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\sobols.xlsx', 
                   df_round, sheet_name=str(i) + '_round')

# %% [markdown]
# #### get delta sobols

# %%
from lca_algebraic.stats import incer_stochastic_matrix_L_return

# %%
sob1, problem1 = incer_stochastic_matrix_L_return([D1], IPCC, n=10000)
sob2, problem2 = incer_stochastic_matrix_L_return([D2], IPCC, n=10000)
sob3, problem3 = incer_stochastic_matrix_L_return([D3], IPCC, n=10000)
sob4, problem4 = incer_stochastic_matrix_L_return([D4], IPCC, n=10000)
sob5, problem5 = incer_stochastic_matrix_L_return([D5], IPCC, n=10000)
sob6, problem6 = incer_stochastic_matrix_L_return([D6], IPCC, n=10000)
sob7, problem7 = incer_stochastic_matrix_L_return([D7], IPCC, n=10000)
sob8, problem8 = incer_stochastic_matrix_L_return([D8], IPCC, n=10000)
sob9, problem9 = incer_stochastic_matrix_L_return([D9], IPCC, n=10000)
sob10, problem10 = incer_stochastic_matrix_L_return([D_CDR], IPCC, n=10000)
# Out:
# Generating samples ...
# C:\Users\lizn0001\Anaconda3\envs\bw2\lib\site-packages\SALib\sample\saltelli.py:94: UserWarning:
#         Convergence properties of the Sobol' sequence is only valid if
#         `N` (10000) is equal to `2^n`.
#
#   warnings.warn(msg)
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')
# ...

# %%
sob10, problem10 = incer_stochastic_matrix_L_return([D_CDR], IPCC, n=10000)
# Out:
# Generating samples ...
# Transforming samples ...
# Processing Sobol indices ...
# Processing sobol for ('IPCC 2013', 'climate change', 'GWP 100a')

# %%
sob_df1 = pd.DataFrame()
sob_df2 = pd.DataFrame()
sob_df3 = pd.DataFrame()
sob_df4 = pd.DataFrame()
sob_df5 = pd.DataFrame()
sob_df6 = pd.DataFrame()
sob_df7 = pd.DataFrame()
sob_df8 = pd.DataFrame()
sob_df9 = pd.DataFrame()
sob_df10 = pd.DataFrame()

# %%
sob_df1_round = pd.DataFrame()
sob_df2_round = pd.DataFrame()
sob_df3_round = pd.DataFrame()
sob_df4_round = pd.DataFrame()
sob_df5_round = pd.DataFrame()
sob_df6_round = pd.DataFrame()
sob_df7_round = pd.DataFrame()
sob_df8_round = pd.DataFrame()
sob_df9_round = pd.DataFrame()
sob_df10_round = pd.DataFrame()

# %%
sob_list = [sob1, sob2, sob3, sob4, sob5, sob6, sob7, sob8, sob9, sob10]
problem_list = [problem1, problem2, problem3, problem4, problem5, problem6, problem7, problem8, 
                problem9, problem10]
sob_df_list = [sob_df1, sob_df2, sob_df3, sob_df4, sob_df5, sob_df6, sob_df7, sob_df8, sob_df9,
              sob_df10]
sob_df_list_round = [sob_df1_round, sob_df2_round, sob_df3_round, sob_df4_round, sob_df5_round, 
            sob_df6_round, sob_df7_round, sob_df8_round, sob_df9_round, sob_df10_round]

# %%
for sob, names, df, df_round in zip(sob_list, problem_list, sob_df_list, sob_df_list_round): # for every scenario
    for s, name in zip(sob.s1, names['names']): # and every sobol & name
        # round-off s
        df[name] = s
        # print(str(round(s[0], 2)))
        #r = str(round(s[0], 2))
        df_round[name] = [str(round(s[0], 2))]

# %%
sob_df2_round
# Out:
#   BiocharDecay BiocharYield CCSElectricityPercentage CCSHeatPercentage  \
# 0          0.0          0.0                      0.0               0.0
#
#   CO2DischargeFromShipElectricity CO2LiquefactionElectricity  \
# 0                            -0.0                        0.0
#
#   CO2LoadingToShipElectricity CO2LongtermStorageLeakage CO2PipelineLeakage  \
# 0                         0.0                      -0.0               -0.0
#
#   CO2StorageInNorwayElectricity  ... CarbonCapturePercentage ElectricityRatio  \
# 0                          -0.0  ...                    0.02              0.0
#
#   LHVWoodchips PowerEfficiency ThermalEfficiency TransportDistanceBiochar  \
# 0          0.0            0.01              0.01                      0.0
#
#   TransportDistanceBiomass TransportDistanceCO2 TransportDistanceSoil  \
# 0                      0.0                  0.0                   0.0
#
#   elec_switch_param
# 0              0.93
#
# [1 rows x 21 columns]

# %%
sob_df2
# Out:
#    BiocharDecay  BiocharYield  CCSElectricityPercentage  CCSHeatPercentage  \
# 0           0.0           0.0                  0.002469           0.000294
#
#    CO2DischargeFromShipElectricity  CO2LiquefactionElectricity  \
# 0                    -2.077654e-08                    0.000174
#
#    CO2LoadingToShipElectricity  CO2LongtermStorageLeakage  CO2PipelineLeakage  \
# 0                     0.000001              -4.009161e-09       -2.327413e-09
#
#    CO2StorageInNorwayElectricity  ...  CarbonCapturePercentage  \
# 0                      -0.000003  ...                 0.018221
#
#    ElectricityRatio  LHVWoodchips  PowerEfficiency  ThermalEfficiency  \
# 0               0.0      0.003952         0.012879           0.006599
#
#    TransportDistanceBiochar  TransportDistanceBiomass  TransportDistanceCO2  \
# 0                       0.0                  0.000023              0.000005
#
#    TransportDistanceSoil  elec_switch_param
# 0                    0.0           0.929381
#
# ...

# %%
# next step: save to excel-files
for i, (df, df_round) in enumerate(zip(sob_df_list, sob_df_list_round)):
   #print(i)
    
    append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\sobols_pair.xlsx', 
                   df, sheet_name=str(i))
                       
    append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\sobols_pair.xlsx', 
                   df_round, sheet_name=str(i) + '_round')

# %% [markdown]
# ### pairwise comparison

# %%
from lca_algebraic.stats import _stochastics
from lca_algebraic.stats import _compute_stochastics
_, params, YD1 = _stochastics([D1], IPCC, n=10000)
YD2 = _compute_stochastics([D2], IPCC, params)
YD3 = _compute_stochastics([D3], IPCC, params)
YD4 = _compute_stochastics([D4], IPCC, params)
YD5 = _compute_stochastics([D5], IPCC, params)
YD6 = _compute_stochastics([D6], IPCC, params)
YD7 = _compute_stochastics([D7], IPCC, params)
YD8 = _compute_stochastics([D8], IPCC, params)
YD9 = _compute_stochastics([D9], IPCC, params)
Y_CDR = _compute_stochastics([D_CDR], IPCC, params)
# Out:
# Generating samples ...
# C:\Users\lizn0001\Anaconda3\envs\bw2\lib\site-packages\SALib\sample\saltelli.py:94: UserWarning:
#         Convergence properties of the Sobol' sequence is only valid if
#         `N` (10000) is equal to `2^n`.
#
#   warnings.warn(msg)
# Transforming samples ...

# %% [markdown]
# Key:
#
# 1,4,7 : BC - CHP
#
# 2,5,8 : BECCS - CHP
#
# 3,6,9: BECCS - BC
#
# This means: S1 = BC wins, S2 = CHP wins
#
# S3 = BECCS wins, S4, CHP wins
#
# etc

# %%
# for later / if i have the time: create a function to save space
CHPd1 = 0
BCd1 = 0
for impact in YD1['climate change - GWP 100a']:
    if impact > 0:
        CHPd1 += 1
    elif impact < 0:
        BCd1 += 1
        
CHPd2 = 0
BECCSd2 = 0
for impact in YD2['climate change - GWP 100a']:
    if impact > 0:
        CHPd2 += 1
    elif impact < 0:
        BECCSd2 += 1
        
BCd3 = 0
BECCSd3 = 0
for impact in YD3['climate change - GWP 100a']:
    if impact > 0:
        BCd3 += 1
    elif impact < 0:
        BECCSd3 += 1
        
CHPd4 = 0
BCd4 = 0
for impact in YD4['climate change - GWP 100a']:
    if impact > 0:
        CHPd4 += 1
    elif impact < 0:
        BCd4 += 1

CHPd5 = 0
BECCSd5 = 0
for impact in YD5['climate change - GWP 100a']:
    if impact > 0:
        CHPd5 += 1
    elif impact < 0:
        BECCSd5 += 1
    
BCd6 = 0
BECCSd6 = 0
for impact in YD6['climate change - GWP 100a']:
    if impact > 0:
        BCd6 += 1
    elif impact < 0:
        BECCSd6 += 1
        
CHPd7 = 0
BCd7 = 0
for impact in YD7['climate change - GWP 100a']:
    if impact > 0:
        CHPd7 += 1
    elif impact < 0:
        BCd7 += 1
        
CHPd8 = 0
BECCSd8 = 0
for impact in YD8['climate change - GWP 100a']:
    if impact > 0:
        CHPd8 += 1
    elif impact < 0:
        BECCSd8 += 1
        
BCd9 = 0
BECCSd9 = 0
for impact in YD9['climate change - GWP 100a']:
    if impact > 0:
        BCd9 += 1
    elif impact < 0:
        BECCSd9 += 1
        
BC_CDR = 0
BECCS_CDR= 0
for impact in Y_CDR['climate change - GWP 100a']:
    if impact > 0:
        BC_CDR += 1
    elif impact < 0:
        BECCS_CDR += 1

# %%
counts_df1 = {}
counts_df1['CHP'] = CHPd1 / (CHPd1 + BCd1)
counts_df1['Biochar'] = BCd1 / (CHPd1 + BCd1)

counts_df2 = {}
counts_df2['CHP'] = CHPd2 / (CHPd2 + BECCSd2)
counts_df2['BECCS'] = BECCSd2 / (CHPd2 + BECCSd2)

counts_df3 = {}
counts_df3['Biochar'] = BCd3 / (BCd3 + BECCSd3)
counts_df3['BECCS'] = BECCSd3 / (BCd3 + BECCSd3)

counts_df4 = {}
counts_df4['CHP'] = CHPd4 / (CHPd4 + BCd4)
counts_df4['Biochar'] = BCd4 / (CHPd4 + BCd4)

counts_df5 = {}
counts_df5['CHP'] = CHPd5 / (CHPd5 + BECCSd5)
counts_df5['BECCS'] = BECCSd5 / (CHPd5 + BECCSd5)

counts_df6 = {}
counts_df6['Biochar'] = BCd6 / (BCd6 + BECCSd6)
counts_df6['BECCS'] = BECCSd6 / (BCd6 + BECCSd6)

counts_df7 = {}
counts_df7['CHP'] = CHPd7 / (CHPd7 + BCd7)
counts_df7['Biochar'] = BCd7 / (CHPd7 + BCd7)

counts_df8 = {}
counts_df8['CHP'] = CHPd8 / (CHPd8 + BECCSd8)
counts_df8['BECCS'] = BECCSd8 / (CHPd8 + BECCSd8)

counts_df9 = {}
counts_df9['Biochar'] = BCd9 / (BCd9 + BECCSd9)
counts_df9['BECCS'] = BECCSd9 / (BCd9 + BECCSd9)

counts_dfCDR = {}
counts_dfCDR['Biochar'] = BC_CDR / (BC_CDR + BECCS_CDR)
counts_dfCDR['BECCS'] = BECCS_CDR / (BC_CDR + BECCS_CDR)

# %%
counts_dfCDR
# Out:
# {'Biochar': 0.9968130434782608, 'BECCS': 0.0031869565217391305}

# %%
# convert to % - multiply w 100

counts_df1 = {}
counts_df1['CHP'] = CHPd1 / (CHPd1 + BCd1) * 100
counts_df1['Biochar'] = BCd1 / (CHPd1 + BCd1) * 100

counts_df2 = {}
counts_df2['CHP'] = CHPd2 / (CHPd2 + BECCSd2) * 100
counts_df2['BECCS'] = BECCSd2 / (CHPd2 + BECCSd2) * 100

counts_df3 = {}
counts_df3['Biochar'] = BCd3 / (BCd3 + BECCSd3) * 100
counts_df3['BECCS'] = BECCSd3 / (BCd3 + BECCSd3) * 100

counts_df4 = {}
counts_df4['CHP'] = CHPd4 / (CHPd4 + BCd4) * 100
counts_df4['Biochar'] = BCd4 / (CHPd4 + BCd4) * 100

counts_df5 = {}
counts_df5['CHP'] = CHPd5 / (CHPd5 + BECCSd5) * 100
counts_df5['BECCS'] = BECCSd5 / (CHPd5 + BECCSd5) * 100

counts_df6 = {}
counts_df6['Biochar'] = BCd6 / (BCd6 + BECCSd6) * 100
counts_df6['BECCS'] = BECCSd6 / (BCd6 + BECCSd6) * 100

counts_df7 = {}
counts_df7['CHP'] = CHPd7 / (CHPd7 + BCd7) * 100
counts_df7['Biochar'] = BCd7 / (CHPd7 + BCd7) * 100

counts_df8 = {}
counts_df8['CHP'] = CHPd8 / (CHPd8 + BECCSd8) * 100
counts_df8['BECCS'] = BECCSd8 / (CHPd8 + BECCSd8) * 100

counts_df9 = {}
counts_df9['Biochar'] = BCd9 / (BCd9 + BECCSd9) * 100
counts_df9['BECCS'] = BECCSd9 / (BCd9 + BECCSd9) * 100

counts_dfCDR = {}
counts_dfCDR['Biochar'] = BC_CDR / (BC_CDR + BECCS_CDR) * 100
counts_dfCDR['BECCS'] = BECCS_CDR / (BC_CDR + BECCS_CDR) * 100

# %%
counts_dfCDR
# Out:
# {'Biochar': 99.68130434782609, 'BECCS': 0.31869565217391305}

# %%
CHPd5 # check that CHP still does not win over BECCS for elec as FU
# Out:
# 0

# %%
df1 = pd.DataFrame(data=counts_df1, index = [1])
df2 = pd.DataFrame(data=counts_df2, index = [1])
df3 = pd.DataFrame(data=counts_df3, index = [1])
df4 = pd.DataFrame(data=counts_df4, index = [1])
df5 = pd.DataFrame(data=counts_df5, index = [1])
df6 = pd.DataFrame(data=counts_df6, index = [1])
df7 = pd.DataFrame(data=counts_df7, index = [1])
df8 = pd.DataFrame(data=counts_df8, index = [1])
df9 = pd.DataFrame(data=counts_df9, index = [1])
df_CDR = pd.DataFrame(data=counts_dfCDR, index = [1])

# %%
# create this to plot two empty plots
empty_dict = {}
empty_dict['CHP'] = 0
empty_dict['Biochar'] = 0
empty_dict['BECCS'] = 0

# %%
empty_df = pd.DataFrame(data=empty_dict, index = [1])

# %%
# combine df:s

dfs = [df1, df2, df3, df4, df5, df6, df7, df8, df9]

single_df = pd.DataFrame({})
for df in dfs:
    single_df=single_df.append(df)
    
single_df['system'] = ['BC-CHP', 'BECCS-CHP', 'BECCS-BC', 'BC-CHP', 'BECCS-CHP', 'BECCS-BC', 'BC-CHP', 'BECCS-CHP', 'BECCS-BC']
single_df['FU'] = ['heat']*3+['elec']*3+['land']*3
single_df.set_index(['system', 'FU'], inplace=True)

# %%
df_CDR2 = pd.DataFrame({})
df_CDR2 = df_CDR2.append(empty_df)
df_CDR2 = df_CDR2.append(empty_df)
df_CDR2 = df_CDR2.append(df_CDR)

# %%
df_CDR2['system'] = ['BC-CHP', 'BECCS-CHP', 'BECCS-BC']

# %%
df_CDR2['FU'] = ['heat']+['elec']+['land']

# %%
df_CDR2.set_index(['system', 'FU'], inplace=True)

# %%
single_df2 = single_df

# %%
single_df2=single_df2.append(df_CDR)

# %%
single_df2
# Out:
#                          CHP    Biochar       BECCS
# (BC-CHP, heat)      0.460217  99.539783         NaN
# (BECCS-CHP, heat)  25.950000        NaN   74.050000
# (BECCS-BC, heat)         NaN  88.958478   11.041522
# (BC-CHP, elec)      0.000870  99.999130         NaN
# (BECCS-CHP, elec)   0.000000        NaN  100.000000
# (BECCS-BC, elec)         NaN   1.319130   98.680870
# (BC-CHP, land)     39.685217  60.314783         NaN
# (BECCS-CHP, land)   0.812609        NaN   99.187391
# (BECCS-BC, land)         NaN   3.013261   96.986739
# 1                        NaN  99.681304    0.318696

# %%
#append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\pairwise_comp.xlsx', 
                   #single_df2, sheet_name='perc2')

# %%
# combine df:s

dfs2 = [df1, df2, df3, df4, df5, df6, df7, df8, df9, empty_df, empty_df, df_CDR]

single_df2 = pd.DataFrame({})
for df in dfs2:
    single_df2=single_df2.append(df)
    
single_df2['system'] = ['BC-CHP', 'BECCS-CHP', 'BECCS-BC', 'BC-CHP', 'BECCS-CHP', 'BECCS-BC', 'BC-CHP', 'BECCS-CHP', 'BECCS-BC', 'BC-CHP', 'BECCS-CHP', 'BECCS-BC']
single_df2['FU'] = ['heat']*3+['elec']*3+['land']*3+['Cseq']*3
single_df2.set_index(['system', 'FU'], inplace=True)

# %%
import matplotlib.colors as mcolors
ranking_colors = mcolors.ListedColormap(['palevioletred', 'darkseagreen', 'skyblue'])

# %%
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(6, 12),)# sharey='row')
axesL = axes.ravel()

colormap = ranking_colors

x_labels = ['Biochar-CHP', 'BECCS-CHP', 'BECCS-Biochar']*4
y_labels = ['Heat']*3+[
            'Electricity']*3+[
            'Biomass']*3 + ['Carbon sequestration']*3

annot = ['a.', 'b.', 'c.', 'd.', 'e.', 'f.', 'g.', 'h.', 'i.', 'pass', 'pass', 'j.']

for i, index_row in enumerate(single_df2.iterrows()):
    system = index_row[0][0]
    funame = index_row[0][1]
    row = pd.DataFrame(index_row[1]).T # just because it's easier with a row as df to use the plot function
    row.plot(kind='bar', stacked=True, colormap=colormap, rot=0, width=0.5,
            ax=axesL[i], legend=None)
    
    axesL[i].axhline(c='black', linewidth=0.5)
    axesL[i].tick_params(axis='x', which='both', labelbottom=False)
    
    axesL[i].set_xlabel(x_labels[i], fontsize=12)
    if (not i % 3) or (i == 11):
        axesL[i].set_ylabel(y_labels[i], fontsize=12)
    else:
        axesL[i].tick_params(axis='y', which='both', labelleft=False)
    
    val2show = row.iloc[0,0]/100 if not np.isnan(row.iloc[0,0]) else row.iloc[0,1]/100 #convert back to decimals
    val2showT = "{:.1%}".format(val2show) if val2show > 0.01 else '<0.01%'
    #val2showT = str(val2show) + '%' if val2show > 0.01 else '<0.01%'
    xpos = 0
    ypos = val2show*100+2 if val2show < 0.1 else val2show*100 - 8 # multiply w 100 to make it match y axis
    axesL[i].annotate(text=val2showT, xy=(xpos,ypos), xycoords='data', fontsize = 11, ha='center') #color, fontweight
    axesL[i].annotate(text=annot[i], xy=(0.03, 0.91), 
                xycoords='axes fraction', fontsize = 14, ha='left', backgroundcolor = 'w',) #fontweight = 'bold')
    
handles, labels = axesL[-1].get_legend_handles_labels()
lgd = fig.legend(handles, labels, ncol = 1, fontsize=16, loc = 'lower left', bbox_to_anchor=(0.3, 0.17), frameon=True, facecolor = 'white', framealpha = 1)

axes[3,0].set_visible(False)
axes[3,1].set_visible(False)

plt.subplots_adjust(top=1, right=1, wspace=0.05, hspace=0.15)

# %%
#fig.savefig('deltasPercentagesAll_v5.jpg', dpi=600, format='jpg', bbox_extra_artists=(lgd,), bbox_inches='tight')

# %% [markdown]
# ## biomass indicators

# %%
def find_demand(to_find, col_names, X):
    for i, key in enumerate(col_names.keys()):
        if key == to_find:
            savekey = key
            key_index = i
    demand = createLambda(0 - X[key_index]) # from neg to pos (bm use is a product)
    
    return demand

# %%
# skip 7-9 since theyre landuse fu
bioenergy_objects = [bioenergy.CombinationsMatrices[1], bioenergy.CombinationsMatrices[2], bioenergy.CombinationsMatrices[3],
                     bioenergy.CombinationsMatrices[4], bioenergy.CombinationsMatrices[5], bioenergy.CombinationsMatrices[6],
                     bioenergyCDR.CombinationsMatrices[1], bioenergyCDR.CombinationsMatrices[2]]

# %%
titles = ['CHP: Heat as FU, biomass per GJ heat (tonnes)', 
         'Biochar: Heat as FU, biomass per GJ heat (tonnes)',
         'BECCS: Heat as FU, biomass per GJ heat (tonnes)',
         'CHP: Electricity as FU, biomass per MWh electricity (tonnes)', 
         'Biochar: Electricity as FU, biomass per MWh electricity (tonnes)',
         'BECCS: Electricity as FU, biomass per MWh electricity (tonnes)',
         'Biochar: C seq as FU, biomass per kg C seq (tonnes)',
         'BECCS: C seq as FU, biomass per kg C seq (tonnes)'
         ]

# %%
stats_dfs = []
for scenario, i in zip(bioenergy_objects, titles):
    demand = find_demand(to_find = ('MyThesisv2', 'soup-land'), 
                    col_names = scenario['A_col_names'], 
                    X = scenario['X'])
    df, res, data = graphs(
        [demand], IPCC,
        axes=None,
        invert=None,
        scales=None, # Dict of method => scale
        unit_overrides=None,
        height=10, width=15,
        func_unit="kWh")
    
    df_new = df.rename(columns={'climate change - GWP 100a [kg CO2-Eq / kWh]': i})
    
    stats_dfs.append(df_new)
# Out:
# Generating samples ...
# C:\Users\lizn0001\Anaconda3\envs\bw2\lib\site-packages\SALib\sample\saltelli.py:94: UserWarning:
#         Convergence properties of the Sobol' sequence is only valid if
#         `N` (10000) is equal to `2^n`.
#
#   warnings.warn(msg)
# Transforming samples ...
# Generating samples ...
# Transforming samples ...
# Generating samples ...
# Transforming samples ...
# Generating samples ...
# Transforming samples ...
# Generating samples ...
# Transforming samples ...
# Generating samples ...
# Transforming samples ...
# Generating samples ...
# Transforming samples ...
# Generating samples ...
# Transforming samples ...

# %%
stats_dfs
# Out:
# [       CHP: Heat as FU, biomass per GJ heat (tonnes)
#  mean                                        0.080214
#  median                                      0.079436
#  p         [0.06761630859749619, 0.09560515337373005]
#  std                                         0.008566
#  var                                         0.106794,
#         Biochar: Heat as FU, biomass per GJ heat (tonnes)
#  mean                                            0.142191
#  median                                          0.139566
#  p             [0.10989498084927177, 0.18294053451486306]
#  std                                             0.022241
#  var                                             0.156416,
#         BECCS: Heat as FU, biomass per GJ heat (tonnes)
#  mean                                          0.064966
#  median                                        0.064338
#  p           [0.05471998897844468, 0.07738990872273001]
#  std                                           0.006962
# ...

# %%
for i, df in enumerate(stats_dfs):
    append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\stats.xlsx', 
                   df, sheet_name=str(i))

# %% [markdown]
# ## Other stuff

# %% [markdown]
# ### create df w params & score

# %%
# create df and save to excel file to make decision trees
from lca_algebraic.stats import _stochastics
from lca_algebraic.stats import _compute_stochastics

prob, paramsForBG, Y1 =_stochastics([L1], IPCC, n=10000)
paramsForBGdf = pd.DataFrame.from_dict(paramsForBG)
# Out:
# Generating samples ...
# C:\Users\lizn0001\Anaconda3\envs\bw2\lib\site-packages\SALib\sample\saltelli.py:94: UserWarning:
#         Convergence properties of the Sobol' sequence is only valid if
#         `N` (10000) is equal to `2^n`.
#
#   warnings.warn(msg)
# Transforming samples ...

# %%
# set up rest of df:s
# already have impacts in Y1 for first case
paramsForBGdf['impactL1'] = Y1.values

Y2 = _compute_stochastics([L2], IPCC, paramsForBG)
paramsForBGdf['impactL2'] = Y2.values
Y3 = _compute_stochastics([L3], IPCC, paramsForBG)
paramsForBGdf['impactL3'] = Y3.values
Y4 = _compute_stochastics([L4], IPCC, paramsForBG)
paramsForBGdf['impactL4'] = Y4.values
Y5 = _compute_stochastics([L5], IPCC, paramsForBG)
paramsForBGdf['impactL5'] = Y5.values
Y6 = _compute_stochastics([L6], IPCC, paramsForBG)
paramsForBGdf['impactL6'] = Y6.values
Y7 = _compute_stochastics([L7], IPCC, paramsForBG)
paramsForBGdf['impactL7'] = Y7.values
Y8 = _compute_stochastics([L8], IPCC, paramsForBG)
paramsForBGdf['impactL8'] = Y8.values
Y9 = _compute_stochastics([L9], IPCC, paramsForBG)
paramsForBGdf['impactL9'] = Y9.values

# %%
# vill även ha värden för CDR som fu
CDR1 = _compute_stochastics([L1_CDR], IPCC, paramsForBG)
paramsForBGdf['impactL10'] = CDR1.values
CDR2 = _compute_stochastics([L2_CDR], IPCC, paramsForBG)
paramsForBGdf['impactL11'] = CDR2.values

# %%
paramsForBGdf.to_excel(r'C:\Users\lizn0001\Desktop\export_dataframe.xlsx')

# %% [markdown]
# ### save df:s to excel

# %% [markdown]
# For some reason we have to create the file before we save data in if, despite the function description telling us that the file will be created (lies!!)

# %%
def append_df_to_excel(filename, df, sheet_name='Sheet1', startrow=None,
                       truncate_sheet=True, 
                       **to_excel_kwargs):
    """
    Append a DataFrame [df] to existing Excel file [filename]
    into [sheet_name] Sheet.
    If [filename] doesn't exist, then this function will create it.

    Parameters:
      filename : File path or existing ExcelWriter
                 (Example: '/path/to/file.xlsx')
      df : dataframe to save to workbook
      sheet_name : Name of sheet which will contain DataFrame.
                   (default: 'Sheet1')
      startrow : upper left cell row to dump data frame.
                 Per default (startrow=None) calculate the last row
                 in the existing DF and write to the next row...
      truncate_sheet : truncate (remove and recreate) [sheet_name]
                       before writing DataFrame to Excel file
      to_excel_kwargs : arguments which will be passed to `DataFrame.to_excel()`
                        [can be dictionary]

    Returns: None

    (c) [MaxU](https://stackoverflow.com/users/5741205/maxu?tab=profile)
    """
    from openpyxl import load_workbook

    # ignore [engine] parameter if it was passed
    if 'engine' in to_excel_kwargs:
        to_excel_kwargs.pop('engine')

    writer = pd.ExcelWriter(filename, engine='openpyxl', mode='a')

    # Python 2.x: define [FileNotFoundError] exception if it doesn't exist 
    try:
        FileNotFoundError
    except NameError:
        FileNotFoundError = IOError


    try:
        # try to open an existing workbook
        writer.book = load_workbook(filename)
        
        # get the last row in the existing Excel sheet
        # if it was not specified explicitly
        if startrow is None and sheet_name in writer.book.sheetnames:
            startrow = writer.book[sheet_name].max_row

        # truncate sheet
        if truncate_sheet and sheet_name in writer.book.sheetnames:
            # re-set startrow
            startrow=0
            # index of [sheet_name] sheet
            idx = writer.book.sheetnames.index(sheet_name)
            # remove [sheet_name]
            writer.book.remove(writer.book.worksheets[idx])
            # create an empty sheet [sheet_name] using old index
            writer.book.create_sheet(sheet_name, idx)
        
        # copy existing sheets
        writer.sheets = {ws.title:ws for ws in writer.book.worksheets}
    except FileNotFoundError:
        # file does not exist yet, we will create it
        pass

    if startrow is None:
        startrow = 0

    # write out the new sheet
    df.to_excel(writer, sheet_name, startrow=startrow, **to_excel_kwargs)

    # save the workbook
    writer.save()

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\notebook_data4.xlsx', 
                   Y1, sheet_name='CA_CHP_heat')

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\notebook_data4.xlsx', 
                   Y2, sheet_name='CA_BC_heat')

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\notebook_data4.xlsx', 
                   Y3, sheet_name='CA_BECCS_heat')

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\notebook_data4.xlsx', 
                   Y4, sheet_name='CA_CHP_elec')

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\notebook_data4.xlsx', 
                   Y5, sheet_name='CA_BC_elec')

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\notebook_data4.xlsx', 
                   Y6, sheet_name='CA_BECCS_elec')

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\notebook_data4.xlsx', 
                   Y7, sheet_name='CA_CHP_bm')

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\notebook_data4.xlsx', 
                   Y8, sheet_name='CA_BC_bm')

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\notebook_data4.xlsx', 
                   Y9, sheet_name='CA_BECCS_bm')

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\notebook_data4.xlsx', 
                   Y1_CDR, sheet_name='CA_BC_co2seq')

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\notebook_data4.xlsx', 
                   Y2_CDR, sheet_name='CA_BECCS_co2seq')

# %%
# save params as well? convert it from dict to df
paramsFordf = pd.DataFrame.from_dict(params)
paramsFordf.head()
# Out:
#    BiocharYield  CO2PipelineLeakage  CO2LongtermStorageLeakage  \
# 0      0.210014            0.000307                   0.005325
# 1      0.252952            0.000307                   0.005325
# 2      0.210014            0.000321                   0.005325
# 3      0.210014            0.000307                   0.004471
# 4      0.210014            0.000307                   0.005325
#
#    TransportDistanceBiomass  TransportDistanceBiochar  ElectricityRatio  \
# 0                420.124412                361.992508           0.28277
# 1                420.124412                361.992508           0.28277
# 2                420.124412                361.992508           0.28277
# 3                420.124412                361.992508           0.28277
# 4                289.240128                361.992508           0.28277
#
#    CarbonCapturePercentage  CO2StorageInVartanElectricity  \
# 0                 0.724811                      11.601471
# ...

# %%
append_df_to_excel(r'C:\Users\lizn0001\Documents\SLU\mexdeluxe\params.xlsx', 
                   paramsFordf, sheet_name='params')
